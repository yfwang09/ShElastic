# %% [markdown]
# # Void-Dislocation Interaction Test Case
#
# The set up of the system can be sketched in the following figure:
#
# <img src="https://raw.githubusercontent.com/yfwang09/ShElastic/master/figures/fig3.png" width="400" />
#
# Based on the analytical solution provided by Gavazza & Barnett (1974), and the implementation in Takahashi and Ghoniem (2008), we have the testcase as following:

# %% [markdown]
# * The solution of the stress:
# $$
# \tau_{yz}(t,0,z)=
# \sum_{n=1}^\infty\left\{-a^{n+1}(2\mu_1\alpha_n+\mu_1\beta_n)+6\mu_1K_n\Omega_n\frac{2n+1}{2n+5}\right\}
#     {1\over r^{n+2}}P^{n-1}_{n+1}
# $$
#
# $$ +
# \sum_{n=1}^\infty\left\{-{1\over2}\mu_1a^{n+1}\beta_n+\mu_1K_n\Omega_n\frac{2n+3}{2n+5}\right\}
#     {1\over r^{n+2}}P^{n+1}_{n+1}
# $$
#
# $$ +
# \sum_{n=1}^\infty\left\{2\mu_1\left({a^2\over r^2}-1\right)K_n\Omega_n+\mu_1K_n\Omega_n\frac{2}{2n+5}\right\}
#     {1\over r^{n+2}}P^{n+1}_{n+3}
# $$
#
# $$ +
# \sum_{n=1}^\infty\left\{24\mu_1\left({a^2\over r^2}-1\right)K_n\Omega_n+\mu_1K_n\Omega_n\frac{24}{2n+5}\right\}
#     {1\over r^{n+2}}P^{n-1}_{n+3}
# $$

# %% [markdown]
# where,
# $$
# K_n=-\frac{\lambda_1 + \mu_1}{2[(n+2)\lambda_1+(3n+5)\mu_1]}
# $$
#
# $$
# \Omega_n=\frac{2\eta_n(\mu_1-\mu_2)a^{2n+1}/t^n}{\mu_1[(n+2)+E_n^I(2n+1)(n+1)]+\mu_2(2n)}
# $$
#
# $$
# \alpha_n=\frac{(\mu_1-\mu_2)\eta_n}{\mu_1(n+2)+\mu_2(n-1)}
# \frac{\mu_1\{(n+2)-E_n^I(2n+1)(n-1)\}}{\mu_1{(n+2)+E_n^I(2n+1)(n+1)}+\mu_2(2n)}
# \left({a\over t}\right)^n
# $$
#
# $$
# \beta_n=\frac{(\mu_2-\mu_1)\eta_n}{\mu_1(n+2)+\mu_2(n-1)}
# \frac{\mu_1\{(n+2)+E_n^I(2n+1)(n-1)\}+2\mu_2(n-1)}{\mu_1{(n+2)+E_n^I(2n+1)(n+1)}+\mu_2(2n)}
# \left({a\over t}\right)^n
# $$
#
# $$
# \eta_n=\left(b\over4\pi\right)\frac{(-1)^n2^n(n-1)!}{(2n-1)!}
# $$
#
# $$
# E_n^I=\frac{1}{2n+1}\frac{(n-1)\lambda_1-(n+4)\mu_1}{(n+2)\lambda_1+(3n+5)\mu_1}
# $$
#
# $P_l^m$ is the *unnormalized Legendre Polynomial* with *Condon-Shortley Phase* coefficients.

# %%
########################## Colab support not available ##########################
# If you run this notebook from colab, run this cell first
# import os
# codepath = '/content/ShElastic'
# if not os.path.exists(codepath):
#     !git clone https://github.com/yfwang09/ShElastic.git 
#     !pip install pyshtools==4.6.2
# os.chdir(os.path.join(codepath, 'examples'))

# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import pyshtools
import sys, os
sys.path.append('..')
from shelastic.shutil import SphCoord_to_CartCoord, CartCoord_to_SphCoord
from shelastic.shutil import SHCilmToVector, lmk2K, K2lmk
from shelastic.SHTest import gavazza1974

# %%
#### Takahashi & Ghoniem (2010) ####
mu1 = 81.8
mu2 = 54.6
nu1 = 0.3
nu2 = 0.25
a = 1.25
b = 0.248

tau_test = loadmat('../testdata/test_takahashi.mat')['Data001']

nmax = 100
zs = np.array([0, ])
ts = tau_test[:, 0]*a*2 #np.linspace(a+2*b, 5*a, 20)

tau_yz = gavazza1974(nmax, zs, ts, mu1, mu2, nu1, nu2, a, b)

print(tau_yz/mu1)
print(tau_test[:,1]/tau_yz)

plt.plot(ts/a/2, tau_yz.T/mu1*1000, '*')
plt.plot(tau_test[:,0], tau_test[:,1])
plt.xlim(0.5,2.5)
plt.ylim(-2.5, 0)
plt.grid(True)
plt.legend(['Analytical Solution', 'Adapted from Takahashi and Ghoniem (2008)'])
plt.savefig('SHanalytical.png', transparent=True)
plt.show()
# Out:
# [[-1.83475557e-03 -1.30113965e-03 -9.45553837e-04 -7.09185252e-04
#   -5.51454440e-04 -4.41503672e-04 -3.58698915e-04 -2.89870771e-04
#   -2.39341981e-04 -2.02935187e-04 -1.66904943e-04 -1.06633838e-04
#   -6.71862441e-05 -3.92569871e-05 -2.21224822e-05 -1.36125393e-05
#   -9.31759425e-06 -6.18232821e-06 -4.27951366e-06 -4.08127499e-06]]
# [[13.53035959 13.60536058 13.88286301 14.04797122 14.20001058 13.84274326
#   13.87702846 14.09186746 14.34265243 13.53233626 13.99206238 13.55994334
#   13.42053031 13.5427718  16.73408771 17.84445382 23.35057123 14.68682461
#   23.7429193  33.68929584]]

# %% [markdown]
# ### Long range Esitimation
#
# The long range esitimation given by Gavazza&Barnett(1974):
#
# $$
# f_x^\infty(t,0,z)=\frac{5\gamma b^2\mu_1a^3}{2\pi t}{1\over r^3}\left(1-2\nu_1+3\nu_1\frac{z^2}{r^2}\right)
# $$
#
# where
# $$
# \gamma=\frac{\Gamma-1}{2\Gamma(4-5\nu_1)+7-5\nu_1},\quad \Gamma={\mu_2\over\mu_1}
# $$

# %% [markdown]
# ### Analytical solution implementation by Willis et al. (1972)
#
# The void-dislocation interaction energy is given:
#
# $$
# E = -\frac{\mu b^2a}{4\pi}\sum_{n=1}^\infty \left({2a\over d}\right)^{2n}\frac{(n-1)!n!}{(2n+1)!}
#     \left[1+\frac{(n+1)+2mn}{n+2}\right]
# $$
#
# where $m = (6-n)/(3n^2+7n+6)$

# %% [markdown]
# The force term is:
#
# $$
# F_1 = {\mu b^2\over2\pi a}\sum_{n=1}^\infty\frac{(-1)^n2^nn!}{(2n)!}\left(a^2\over rd\right)^nz
#     \left\{P_{n+1}^{n-1}(\cos\theta)\left(\frac{1+(2n-1)m}{n+2}\right)
#           -\frac{1+m}{2(n+2)}P_{n+1}^{n+1}(\cos\theta)
#           +{3\over l}cos\theta(P_{n+2}^{n+1}(\cos\theta)+P_{n+2}^{n-1}(\cos\theta))
#           -{6\over l}(1-z)(P_{n+3}^{n+1}(\cos\theta)+12P_{n+3}^{n-1}(\cos\theta))
#     \right\}
# $$
#
# where $z=(a/r)^2$ and $l=2(3n^2+7n+6)$

# %%
from shelastic.SHTest import willis1972
from scipy.special import factorial

d = np.linspace(1.5, 3.0)
a = 1
a_d = a/d
nmax = 41
x3 = np.linspace(0, 20)

F1, Fa, F, E = willis1972(a, d, nmax, x3)

# %%
#print(d.shape, E.shape, F.shape)
#print(E)
Ep = np.gradient(E, d)

plt.plot(d, Ep, label='numerical energy')
plt.plot(d, 2*F, '*', label='analytical energy')
plt.xlabel('distance from center of the void (d/a)')
plt.ylabel('elastic energy')
plt.legend()
plt.show()

# %%
a = 40
t = a*1.01
b = 1
mu = 1
nu = 1./3
x3zT= np.linspace(0, 3, 50)
x3z = np.linspace(0, 3, 50)
tau_yz = gavazza1974(40, x3zT*a, [t, ], mu, 0, nu, nu, a, b)
F1, Fa, F, E = willis1972(a, t, 40, x3z*a, mu, b)
plt.plot(x3zT, -tau_yz, 'o', label='Stress from Gavazza(1974)')
plt.plot(x3z, F1.flatten(), label='Stress from Willis(1972)')
plt.xlabel('distance')
plt.ylabel(r'$\sigma_{yz}$')
plt.legend()
# print(tau_yz.flatten()*b/np.sum(F1[:, :], axis=1))
plt.show()

# %% [markdown]
# ## Implement Solution in ShElastic
#
# First we import the libraries we developed:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyshtools
import sys
sys.path.append('..')
from shelastic.shutil import SphCoord_to_CartCoord, CartCoord_to_SphCoord
from shelastic.shutil import SHCilmToVector, lmk2K, K2lmk
from shelastic.shvis  import plotfv

# %% [markdown]
# Then we generate the meshgrid on the void surface for boundary conditions.

# %%
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from mpl_toolkits.mplot3d import Axes3D

#### Gavazza & Barnett (1974) ####
mu = 2.65
nu = 0.347
a = 1
b = 1
t = ts[0]

#### Willis, Hayns & Bullough (1972) ####
r0 = 1 #r0= 1.25

mu0 = 1 #mu0= 81.8        # GPa
nu = 1./3 #nu = 0.305
b0 = 1 #b0 = 0.25
t0= 1.5*r0
x0 = np.linspace(0, 3, 30)*r0

mu= mu0/mu0
a = 1.0
b = b0/r0
t = t0/r0
x3= x0/r0

# zs = np.linspace(0,6,50)
# ts = [t, ]

#### traction mode matrix info ####
modepath = '../shelastic/default_modes'
lJmax = 43 # max l degree for saving a single mode
lKmax = 40 # max cutoff l degree for modes
LJ = (lJmax+1)**2
LK = (lKmax+1)**2

#### create meshgrid for evaluation ####
## DH2 mesh
#Ngrid = 100
#theta = (np.arange(0,Ngrid)+0.0)/Ngrid*(np.pi)
#phi = (np.arange(0,2*Ngrid)+0.0)/(2*Ngrid)*(2*np.pi)
## GLQ mesh
latglq, longlq = pyshtools.expand.GLQGridCoord(lJmax, extend=True)
theta = np.deg2rad(90 - latglq)
phi = np.deg2rad(longlq)

THETA,PHI = np.meshgrid(theta, phi)
R = np.ones_like(THETA)
X, Y, Z = SphCoord_to_CartCoord(R, THETA, PHI)
N = -np.stack((X/R, Y/R, Z/R), axis=-1)

# %% [markdown]
# Then we evaluate traction boundary conditions on the spherical surface. We have a spherical void center at the origin with radius $a$, and a RH screw dislocation at $(t,0,0)$, with $\hat{\xi}=\hat{\mathbf{e}}_z$, with a burger's vector magnitude of $b$. The stress field induced by the dislocation in an infinite medium can be written as $\mathbf{\sigma}^\infty$, with the only two non-zero terms:
#
# $$
# \sigma_{xz}^\infty = -\frac{\mu b}{2\pi}\frac{y}{(x-t)^2+y^2} \\
# \sigma_{yz}^\infty = \frac{\mu b}{2\pi}\frac{x-t}{(x-t)^2+y^2}
# $$

# %%
#### generate boundary condition ####
sigma_inf = np.zeros(THETA.shape+(3, 3))
mub = mu*b
sigma_inf[:, :, 0, 2] = -mub/2/np.pi * Y/((X-t)**2+Y**2)
sigma_inf[:, :, 2, 0] = -mub/2/np.pi * Y/((X-t)**2+Y**2)
sigma_inf[:, :, 1, 2] =  mub/2/np.pi * (X-t)/((X-t)**2+Y**2)
sigma_inf[:, :, 2, 1] =  mub/2/np.pi * (X-t)/((X-t)**2+Y**2)

print(sigma_inf.shape)

sigma_0 = sigma_inf; sigma_inf = sigma_0/mu0
T_inf = np.einsum('ijkl,ijl->ijk', sigma_0, N)

T_usr_mesh = T_inf.astype(np.complex)
print(T_usr_mesh.shape)

ttl = ['$T_x$','$T_y$','$T_z$']
T_usr_vec = np.empty(3*LJ, dtype=np.complex)
for k in range(3):
    fig, ax = plotfv(T_usr_mesh[:,:,k].real.T, show=False)
    ax.set_title(ttl[k])
    T_usr_grid = pyshtools.SHGrid.from_array(T_usr_mesh[...,k].T, grid='GLQ')
    T_usr_grid.plot3d(elevation=20, azimuth=45)
    T_usr_cilm = T_usr_grid.expand()
    T_usr_vec[LJ*k:LJ*(k+1)] = SHCilmToVector(T_usr_cilm.to_array(), lmax = lJmax)
plt.show()
# Out:
# (88, 44, 3, 3)
# (88, 44, 3)
# c:\Users\yfwan\anaconda3\envs\ShElastic\lib\site-packages\pyshtools\shclasses\shcoeffsgrid.py:3672: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Then we expand the traction boundary conditions to spherical harmonic modes:

# %%
#### load the full and sub matrix ####
import time
import scipy.sparse as spm
from scipy.io import loadmat, savemat
from shelastic.shelastic import calSmode
from shelastic.shbv import generate_submat

ticT = time.time()
shtype = 'irr'
Tmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
Cmat = generate_submat(Tmodes, mu, nu, lKmax, lJmax, shtype=shtype)
Umodes = loadmat(os.path.join(modepath, 'Umodes.mat'))
Dmat = generate_submat(Umodes, mu, nu, lKmax, lJmax, shtype=shtype)
Smodes = loadmat(os.path.join(modepath, 'Smodes.mat'))
Smodes = generate_submat(Smodes, mu, nu, lKmax, lJmax, shtype=shtype)
tocT = time.time()
print('Time for loading SH modes: %.4fs'%(tocT-ticT))
# Out:
# Time for loading SH modes: 1.8853s

# %% [markdown]
# Then we solve for the linear problem:

# %%
from shelastic.shbv import print_SH_mode
from scipy.sparse.linalg import lsqr
import time

tic = time.time()
A = lsqr(Cmat, T_usr_vec.transpose())
toc = time.time()
print('Residual:', A[3], 'Time:', toc-tic)
A_sol = np.zeros_like(A[0])
A_sol[np.abs(A[0]) > 1e-8] = A[0][np.abs(A[0]) > 1e-8]
print('Solution Size:', A_sol.size)
#index_sol = print_SH_mode(A_sol, m_dir=3)
# Out:
# Residual: 1.4670210961014987e-05 Time: 1.8480348587036133
# Solution Size: 5043

# %%
print(A_sol.shape[0], lKmax, lJmax)
# Out:
# 5043 40 43

# %% [markdown]
# Then we reconstruct the stress solution on spherical surface from the spherical harmonic solution:

# %%
from shelastic.shbv import fast_stress_solution

tic = time.time()
sigma_tot = fast_stress_solution(A_sol, X, Y, Z, Smodes, lKmax, lJmax)
toc = time.time()
print(sigma_tot.shape, toc-tic)

T_sol = np.sum(sigma_tot*N[...,np.newaxis,:], axis=-1)

for k in range(3):
    T_sol_grid = pyshtools.SHGrid.from_array(T_sol[...,k].T, grid='GLQ')
    fig, ax = plotfv(T_sol_grid.to_array())
    #T_sol_grid.plot()#3d(elevation=20, azimuth=-45)
# Out:
# (88, 44, 3, 3) 35.63820743560791

# %% [markdown]
# Reconstruct stress solution on x-axis for comparison to analytical solution

# %%
from shelastic.shbv import fast_stress_solution

xs, ys, zs = np.meshgrid([t, ], [0, ], x3)

tic = time.time()
sigma_tot = fast_stress_solution(A_sol, xs, ys, zs, Smodes, lKmax, lJmax)
toc = time.time()
print(sigma_tot.shape, toc-tic)

print(sigma_tot[...,1,2].shape)
tau_ShE = sigma_tot[...,1,2].flatten()

x3zT= np.linspace(0, 3, 50)*r0
x3z = np.linspace(0, 3, 100)*r0

tau_yz = gavazza1974(50, x3zT, [t0, ], mu0, 0, nu, nu, r0, b0)
#F1, Fa, F = willis1972(r0, t0, 50, x3z,mu=mu0,b=b0)

plt.figure()
plt.plot(x3zT/r0, -tau_yz/mu0*r0, label='Gavazza&Barnett(1974)')
#plt.plot(x3z, np.sum(F1[:, :], axis=1)/b0, '--')
plt.plot(x3, -tau_ShE.flatten()*r0, '^', label='ShElastic')
plt.xlabel(r'$z/r_0$', fontsize=20)
plt.xlim(0, 3)
#plt.ylim(0, 8)
plt.ylabel(r'$\tau_{yz}r_0/\mu$', fontsize=20)
plt.tick_params(labelsize=14)
plt.tight_layout()
plt.legend(fontsize=14)
plt.show()
# Out:
# (1, 1, 30, 3, 3) 0.8606665134429932
# (1, 1, 30)

# %%
t0 = 1.5*r0

FEM = loadmat('../testdata/screw.mat')['M']
print(FEM.shape)
xrange = np.linspace(FEM[:,0].min(), FEM[:,0].max())

xs, ys, zs = np.meshgrid(xrange, [0, ], [0, ])
tic = time.time()
sigma_tot = fast_stress_solution(A_sol, xs, ys, zs, Smodes, lKmax, lJmax)
toc = time.time()
print(sigma_tot.shape, toc-tic)

xs, ys, zs = np.meshgrid(FEM[:, 0], [0, ], [0, ])
sigma_sol = fast_stress_solution(A_sol, xs, ys, zs, Smodes, lKmax, lJmax)[...,1,2].flatten()
plt.plot(xrange, sigma_tot[...,1, 2].flatten(), label='ShElastic')
plt.plot(FEM[:, 0], -FEM[:, 1], '*', label='FEM')
plt.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.xlabel('Distance from void center $x/r_0$', fontsize=20)
plt.ylabel(r'$\sigma_{yz}/\mu$', fontsize=20)
print('error: ', np.abs((sigma_sol+FEM[:,1])/np.abs(sigma_sol).max()))
plt.tight_layout()
plt.savefig('../figures/case2-FEM.png', transparent=True) #, dpi=1000))
plt.show()
# Out:
# (16, 2)
# (1, 50, 1, 3, 3) 1.2228426933288574
# error:  [0.01103882 0.0249065  0.02624794 0.02454915 0.00640487 0.00657449
#  0.0055313  0.01007098 0.01303863 0.00131363 0.00154938 0.00829328
#  0.00373959 0.00639886 0.00333986 0.00370687]

# %%
# save the data to matfile
from scipy.io import savemat, whosmat

n = 2
filename = '../figures/case2-FEM.mat'
obj_x = np.empty((n,), dtype=np.object)
obj_y = np.empty((n,), dtype=np.object)
obj_label = np.empty((n,), dtype=np.object)

obj_x[0], obj_x[1] = (xrange, FEM[:, 0])
obj_y[0], obj_y[1] = (sigma_tot[...,1,2].flatten(), FEM[:, 1])
obj_label[0] = 'ShElastic'
obj_label[1] = 'FEM'

savemat(filename, {'X': obj_x, 'Y': obj_y, 'label': obj_label})
whosmat(filename)
#print(loadmat(filename)['label'])
# Out:
# [('X', (1, 2), 'cell'), ('Y', (1, 2), 'cell'), ('label', (1, 2), 'cell')]

# %% [markdown]
# ### The convergence of the ShElastic solution
#
# We next generate the solution using different degrees of spherical harmonics to get accuracy curve:

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as spm
import pyshtools

from shelastic.shutil import SphCoord_to_CartCoord, CartCoord_to_SphCoord
from shelastic.shutil import SHVectorToCilm, SHCilmToVector, lmk2K, K2lmk
from shelastic.shbv import fast_stress_solution, generate_submat, fast_energy_solution
from shelastic.shelastic import calUmode, calSmode
import time

# %%
def visSHVec(xvec, lmax_plot=None, cmap='viridis', show=True, 
             SphCoord=True, config_quiver=(2, 4, 'k', 1), 
             lonshift=0, Complex=False, mesh=False):
    if lmax_plot is None:
        lmax_plot = (np.sqrt(xvec.size/3) - 1).astype(np.int)
    cvec = xvec.reshape(3, -1)
    nvec = cvec.shape[1]
    xmesh= [None for _ in range(3)]
    for k in range(3):
        if Complex:
            cext = np.zeros((lmax_plot+1)**2, dtype=np.complex)
            cext[:nvec] = cvec[k, :]
            cilm = SHVectorToCilm(cext)
        else:
            cext = np.zeros((lmax_plot+1)**2)
            cext[:nvec] = cvec[k, :]
            cilm = pyshtools.shio.SHVectorToCilm(cext)
        coeffs = pyshtools.SHCoeffs.from_array(cilm)
        grid = coeffs.expand('GLQ')
        xmesh[k] = grid.to_array().real
    xmesh = np.stack(xmesh, axis=-1)
    if SphCoord:
        Q = TransMat(lJmax=lmax_plot)
        xmesh = np.sum(Q*xmesh[...,np.newaxis,:], axis=-1)
        
        fig = [None for _ in range(2)]
        ax = [None for _ in range(2)]
        xshear= np.linalg.norm(xmesh[...,1:], axis=-1)
        
        fig[0], ax[0] = plotfv(xmesh[...,0], show=False, cmap=cmap, vrange=(-200, 200), lonshift=lonshift)
        ax[0].set_title('norm')
        
        fig[1], ax[1] = plotfv(xshear, show=False, cmap='Reds', lonshift=lonshift)
        lons, lats = np.meshgrid(grid.lons(), grid.lats())
        xshift = np.roll(xmesh, np.round(lons.shape[1]*lonshift/360).astype(np.int), axis=1)
        st, dq, color, scale = config_quiver
        ax[1].quiver(lons[::dq,st::dq], lats[::dq,st::dq], 
                     xshift[::dq,st::dq,1], xshift[::dq,st::dq,2], 
                     color=color, scale=scale)
        ax[1].set_title('shear')
    else:
        fig = [None for _ in range(3)]
        ax = [None for _ in range(3)]
        titlestr = ('x', 'y', 'z')
        for k in range(3):
            fig[k], ax[k] = plotfv(xmesh[...,k], show=False, cmap=cmap, lonshift=lonshift)
            ax[k].set_title('$'+titlestr[k]+'$')
    if show:
        plt.show()
    if mesh:
        return xmesh
    return fig, ax

# %%
def tauyz_ShElastic(lKmax, z0, t0, r0, b0, mu0=None, nu=None, Tmodes=None, Smodes=None, Umodes=None, Tcmodes=None, Ucmodes=None):
    tic = time.time()
    if mu0 is None:
        mu0 = 1.0
    mu = 1.0; r = 1.0; b = b0/r0; t = t0/r0; x3 = z0/r0;
    lJmax = lKmax + 3; LJ = (lJmax+1)**2;
    latglq, longlq = pyshtools.expand.GLQGridCoord(lJmax)
    theta = np.deg2rad(90 - latglq)
    phi = np.deg2rad(longlq)
    THETA,PHI = np.meshgrid(theta, phi)
    R = np.ones_like(THETA)
    X, Y, Z = SphCoord_to_CartCoord(R, THETA, PHI)
    N = -np.stack((X/R, Y/R, Z/R), axis=-1)
    print('constructing grids...', N.shape)
    
    u_inf = np.zeros(THETA.shape + (3, ))
    u_inf[..., 2] = np.arctan2(Y, (X-t))
    u_inf[u_inf < 0] += 2*np.pi
    u_inf *= b/2/np.pi
    u_inf[...,2] -= b/2

    sigma_inf = np.zeros(THETA.shape+(3, 3))
    sigma_inf[..., 0, 2] = -mu*b/2/np.pi * Y/((X-t)**2+Y**2)
    sigma_inf[..., 2, 0] =  sigma_inf[..., 0, 2]
    sigma_inf[..., 1, 2] =  mu*b/2/np.pi * (X-t)/((X-t)**2+Y**2)
    sigma_inf[..., 2, 1] =  sigma_inf[..., 1, 2]
    print('calculating infinite stress field...', sigma_inf.shape)

    T_inf = np.einsum('ijkl,ijl->ijk', sigma_inf, N)
    T_usr_mesh = T_inf.astype(np.complex)
    T_usr_vec = np.empty(3*LJ, dtype=np.complex)
    for k in range(3):
        T_usr_grid = pyshtools.SHGrid.from_array(T_usr_mesh[...,k].T, grid='GLQ')
        #plotfv(T_inf[...,k].T)
        T_usr_cilm = T_usr_grid.expand()
        T_usr_vec[LJ*k:LJ*(k+1)] = SHCilmToVector(T_usr_cilm.to_array(), lmax = lJmax)
    toc = time.time()
    print('setting up the boundary condition...', toc-tic)

    ticT = time.time()
    shtype = 'irr'
    Tmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
    Cmat = generate_submat(Tmodes, mu, nu, lKmax, lJmax, shtype=shtype)
    Smodes = loadmat(os.path.join(modepath, 'Smodes.mat'))
    Smodes = generate_submat(Smodes, mu, nu, lKmax, lJmax, shtype=shtype)
    tocT = time.time()
    print('Time for loading SH modes: %.4fs'%(tocT-ticT))

    tic = time.time()
    A = spm.linalg.lsqr(Cmat, T_usr_vec.T)
    toc = time.time()
    solve_time=toc-tic
    print('Residual:', A[3], 'Solving time:', toc-tic)
    A_sol = np.zeros_like(A[0])
    a_err = 1e-10
    A_sol[np.abs(A[0]) > a_err] = A[0][np.abs(A[0]) > a_err]
    n_active = A_sol.nonzero()[0].size
    print('Solution:', A_sol.size, 'Active modes:', n_active)

    xs, ys, zs = np.meshgrid([t, ], [0, ], x3)
    tic = time.time()
    sigma_tot = fast_stress_solution(A_sol, xs, ys, zs, Smodes, lKmax, lJmax)
    toc = time.time()
    reconstruct_time=toc-tic
    print('reconstruction time:', toc-tic)

    if Umodes is not None:
        Umodes = loadmat(os.path.join(modepath, 'Umodes.mat'))
        Dmat = generate_submat(Umodes, mu, nu, lKmax, lJmax, shtype=shtype)
        if Ucmodes is not None:
            shtype = 'reg'
            Ccmat = generate_submat(Tmodes, mu, nu, lKmax, lJmax, shtype=shtype)
            Dcmat = generate_submat(Umodes, mu, nu, lKmax, lJmax, shtype=shtype)
            Ac = spm.linalg.lsqr(Ccmat, -T_usr_vec.T)
            E_el = fast_energy_solution(A[0], Dmat, Cmat, Ac_sol=Ac[0], Dcmat=Dcmat, Ccmat=Ccmat)
            return (sigma_tot*mu0, n_active, E_el*mu0*r0**3, solve_time, reconstruct_time)
        else:
            E_b = fast_energy_solution(A[0], Dmat, Cmat)
            return (sigma_tot*mu0, n_active, E_b*mu0*r0**3, solve_time, reconstruct_time)
    else:
        return (sigma_tot*mu0, n_active, solve_time, reconstruct_time)

# %%
a = 1.25; b = 0.25; t = 1.5*a; # nm
mu = 52.5; nu = 1./3; 
x3 = np.linspace(0, 3)

analytical = gavazza1974(80, x3*a, [t, ], mu, 0, nu, nu, a, b)
mode_list = np.arange(30, 0, -1) #np.hstack((np.arange(1, 5), np.arange(5, 41, 5)))[::-1]
fx_list = []
active_list = []
solve_time = []
reconstruct_time = []
error_list = []
shtype = 'irr'
Tmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
Smodes = loadmat(os.path.join(modepath, 'Smodes.mat'))

for lKmax in mode_list:
    print('lKmax =', lKmax)
    sigma, act_mode, tsolve, tconstruct = tauyz_ShElastic(lKmax, x3*a, t, a, b, mu0=mu, nu=nu, Tmodes=Tmodes, Smodes=Smodes)
    err = np.absolute((sigma[:,:,:,1,2].flatten()-analytical.flatten())/analytical.flatten()).max()
    print('relative error =', err)
    error_list.append(err)
    fx_list.append(sigma)
    active_list.append(act_mode)
    solve_time.append(tsolve)
    reconstruct_time.append(tconstruct)
# Out:
# lKmax = 30
# constructing grids... (67, 34, 3)
# calculating infinite stress field... (67, 34, 3, 3)
# setting up the boundary condition... 0.04960823059082031
# Time for loading SH modes: 0.3976s
# Residual: 1.1011074727090235e-06 Solving time: 0.7932987213134766
# Solution: 2883 Active modes: 348
# reconstruction time: 0.8741014003753662
# relative error = 3.532980923263898e-06
# lKmax = 29
# constructing grids... (65, 33, 3)
# calculating infinite stress field... (65, 33, 3, 3)
# setting up the boundary condition... 0.006981611251831055
# Time for loading SH modes: 0.3167s
# Residual: 1.013042936481289e-06 Solving time: 0.4472639560699463
# Solution: 2700 Active modes: 329
# reconstruction time: 1.0196192264556885
# relative error = 3.902266798095028e-06
# lKmax = 28
# constructing grids... (63, 32, 3)
# calculating infinite stress field... (63, 32, 3, 3)
# setting up the boundary condition... 0.015620708465576172
# Time for loading SH modes: 0.3915s
# Residual: 9.533760866697618e-07 Solving time: 0.5551314353942871
# Solution: 2523 Active modes: 328
# reconstruction time: 1.2101678848266602
# relative error = 4.874274151989612e-06
# lKmax = 27
# constructing grids... (61, 31, 3)
# calculating infinite stress field... (61, 31, 3, 3)
# setting up the boundary condition... 0.19061851501464844
# Time for loading SH modes: 0.3423s
# Residual: 8.7681491998776e-07 Solving time: 0.6056084632873535
# Solution: 2352 Active modes: 302
# reconstruction time: 0.8284749984741211
# relative error = 5.115608077252506e-06
# lKmax = 26
# constructing grids... (59, 30, 3)
# calculating infinite stress field... (59, 30, 3, 3)
# setting up the boundary condition... 0.31223535537719727
# Time for loading SH modes: 0.4082s
# Residual: 8.046389085052811e-07 Solving time: 0.42176079750061035
# Solution: 2187 Active modes: 326
# reconstruction time: 0.8834562301635742
# relative error = 5.3986971048064365e-06
# lKmax = 25
# constructing grids... (57, 29, 3)
# calculating infinite stress field... (57, 29, 3, 3)
# setting up the boundary condition... 0.01562047004699707
# Time for loading SH modes: 0.5802s
# Residual: 7.506734491711326e-07 Solving time: 0.4210631847381592
# Solution: 2028 Active modes: 326
# reconstruction time: 1.06099534034729
# relative error = 5.722390708755239e-06
# lKmax = 24
# constructing grids... (55, 28, 3)
# calculating infinite stress field... (55, 28, 3, 3)
# setting up the boundary condition... 0.0077130794525146484
# Time for loading SH modes: 0.4535s
# Residual: 6.771993422008764e-07 Solving time: 0.35199904441833496
# Solution: 1875 Active modes: 275
# reconstruction time: 0.8975605964660645
# relative error = 5.848925474978457e-06
# lKmax = 23
# constructing grids... (53, 27, 3)
# calculating infinite stress field... (53, 27, 3, 3)
# setting up the boundary condition... 0.11197853088378906
# Time for loading SH modes: 0.3880s
# Residual: 8.618789366394635e-07 Solving time: 0.47606635093688965
# Solution: 1728 Active modes: 258
# reconstruction time: 0.9664583206176758
# relative error = 6.112371967207714e-08
# lKmax = 22
# constructing grids... (51, 26, 3)
# calculating infinite stress field... (51, 26, 3, 3)
# setting up the boundary condition... 0.015628337860107422
# Time for loading SH modes: 0.4728s
# Residual: 1.3234062862827337e-06 Solving time: 0.2971024513244629
# Solution: 1587 Active modes: 246
# reconstruction time: 0.7727065086364746
# relative error = 1.364075157744663e-07
# lKmax = 21
# constructing grids... (49, 25, 3)
# calculating infinite stress field... (49, 25, 3, 3)
# setting up the boundary condition... 0.01599431037902832
# Time for loading SH modes: 0.3069s
# Residual: 2.0347732643901654e-06 Solving time: 0.3510298728942871
# Solution: 1452 Active modes: 234
# reconstruction time: 0.7198216915130615
# relative error = 3.0399246887303296e-07
# lKmax = 20
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.28670287132263184
# Time for loading SH modes: 0.3762s
# Residual: 3.1331033375736825e-06 Solving time: 0.3176271915435791
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6500787734985352
# relative error = 6.764512122341392e-07
# lKmax = 19
# constructing grids... (45, 23, 3)
# calculating infinite stress field... (45, 23, 3, 3)
# setting up the boundary condition... 0.015620708465576172
# Time for loading SH modes: 0.5815s
# Residual: 4.832130200938837e-06 Solving time: 0.3837621212005615
# Solution: 1200 Active modes: 216
# reconstruction time: 0.7605533599853516
# relative error = 1.5023394540058218e-06
# lKmax = 18
# constructing grids... (43, 22, 3)
# calculating infinite stress field... (43, 22, 3, 3)
# setting up the boundary condition... 0.15606093406677246
# Time for loading SH modes: 0.4285s
# Residual: 7.4660087900548726e-06 Solving time: 0.1623382568359375
# Solution: 1083 Active modes: 208
# reconstruction time: 0.7113475799560547
# relative error = 3.329516915791103e-06
# lKmax = 17
# constructing grids... (41, 21, 3)
# calculating infinite stress field... (41, 21, 3, 3)
# setting up the boundary condition... 0.0780186653137207
# Time for loading SH modes: 0.5015s
# Residual: 1.1558968348159936e-05 Solving time: 0.1319420337677002
# Solution: 972 Active modes: 206
# reconstruction time: 0.7331523895263672
# relative error = 7.346475687756189e-06
# lKmax = 16
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.015496253967285156
# Time for loading SH modes: 0.4888s
# Residual: 1.7936697366120033e-05 Solving time: 0.22201061248779297
# Solution: 867 Active modes: 214
# reconstruction time: 0.783022403717041
# relative error = 1.618789772166202e-05
# lKmax = 15
# constructing grids... (37, 19, 3)
# calculating infinite stress field... (37, 19, 3, 3)
# setting up the boundary condition... 0.09829163551330566
# Time for loading SH modes: 0.3151s
# Residual: 2.790568295545124e-05 Solving time: 0.16015362739562988
# Solution: 768 Active modes: 214
# reconstruction time: 0.4859795570373535
# relative error = 3.5528515751860323e-05
# lKmax = 14
# constructing grids... (35, 18, 3)
# calculating infinite stress field... (35, 18, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4476s
# Residual: 4.354430101508687e-05 Solving time: 0.1532750129699707
# Solution: 675 Active modes: 218
# reconstruction time: 0.43228697776794434
# relative error = 7.761938464056936e-05
# lKmax = 13
# constructing grids... (33, 17, 3)
# calculating infinite stress field... (33, 17, 3, 3)
# setting up the boundary condition... 0.0038459300994873047
# Time for loading SH modes: 0.4162s
# Residual: 6.817986438857044e-05 Solving time: 0.1174623966217041
# Solution: 588 Active modes: 216
# reconstruction time: 0.32715511322021484
# relative error = 0.00016862851171799834
# lKmax = 12
# constructing grids... (31, 16, 3)
# calculating infinite stress field... (31, 16, 3, 3)
# setting up the boundary condition... 0.05976104736328125
# Time for loading SH modes: 0.4577s
# Residual: 0.00010717957127613544 Solving time: 0.050168752670288086
# Solution: 507 Active modes: 220
# reconstruction time: 0.35204386711120605
# relative error = 0.00036364401778251184
# lKmax = 11
# constructing grids... (29, 15, 3)
# calculating infinite stress field... (29, 15, 3, 3)
# setting up the boundary condition... 0.08511924743652344
# Time for loading SH modes: 0.3835s
# Residual: 0.00016928068617013653 Solving time: 0.015620946884155273
# Solution: 432 Active modes: 194
# reconstruction time: 0.4059104919433594
# relative error = 0.0007857630089907013
# lKmax = 10
# constructing grids... (27, 14, 3)
# calculating infinite stress field... (27, 14, 3, 3)
# setting up the boundary condition... 0.015621185302734375
# Time for loading SH modes: 0.3096s
# Residual: 0.0002688673866859594 Solving time: 0.02674245834350586
# Solution: 363 Active modes: 165
# reconstruction time: 0.2902817726135254
# relative error = 0.0017158802471123884
# lKmax = 9
# constructing grids... (25, 13, 3)
# calculating infinite stress field... (25, 13, 3, 3)
# setting up the boundary condition... 0.009389162063598633
# Time for loading SH modes: 0.3631s
# Residual: 0.00042995553370416716 Solving time: 0.056201934814453125
# Solution: 300 Active modes: 133
# reconstruction time: 0.22531580924987793
# relative error = 0.003782688992936543
# lKmax = 8
# constructing grids... (23, 12, 3)
# calculating infinite stress field... (23, 12, 3, 3)
# setting up the boundary condition... 0.01659226417541504
# Time for loading SH modes: 0.4105s
# Residual: 0.0006933682179940138 Solving time: 0.015620708465576172
# Solution: 243 Active modes: 108
# reconstruction time: 0.17352628707885742
# relative error = 0.00824391012278363
# lKmax = 7
# constructing grids... (21, 11, 3)
# calculating infinite stress field... (21, 11, 3, 3)
# setting up the boundary condition... 0.02114582061767578
# Time for loading SH modes: 0.3196s
# Residual: 0.0011301462773916167 Solving time: 0.015623331069946289
# Solution: 192 Active modes: 84
# reconstruction time: 0.20310330390930176
# relative error = 0.017903652063271068
# lKmax = 6
# constructing grids... (19, 10, 3)
# calculating infinite stress field... (19, 10, 3, 3)
# setting up the boundary condition... 0.004562854766845703
# Time for loading SH modes: 0.2876s
# Residual: 0.001867896154571662 Solving time: 0.0
# Solution: 147 Active modes: 63
# reconstruction time: 0.12115359306335449
# relative error = 0.038809035579082427
# lKmax = 5
# constructing grids... (17, 9, 3)
# calculating infinite stress field... (17, 9, 3, 3)
# setting up the boundary condition... 0.01562190055847168
# Time for loading SH modes: 0.3528s
# Residual: 0.0031461563421809947 Solving time: 0.004311561584472656
# Solution: 108 Active modes: 45
# reconstruction time: 0.061014652252197266
# relative error = 0.08368561667676078
# lKmax = 4
# constructing grids... (15, 8, 3)
# calculating infinite stress field... (15, 8, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3000s
# Residual: 0.005444523378633632 Solving time: 0.01562356948852539
# Solution: 75 Active modes: 30
# reconstruction time: 0.04628777503967285
# relative error = 0.17869449059109863
# lKmax = 3
# constructing grids... (13, 7, 3)
# calculating infinite stress field... (13, 7, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3317s
# Residual: 0.009820122223851403 Solving time: 0.015621423721313477
# Solution: 48 Active modes: 18
# reconstruction time: 0.031242847442626953
# relative error = 0.381058246040029
# lKmax = 2
# constructing grids... (11, 6, 3)
# calculating infinite stress field... (11, 6, 3, 3)
# setting up the boundary condition... 0.010056734085083008
# Time for loading SH modes: 0.2389s
# Residual: 0.01896042794791997 Solving time: 0.0
# Solution: 27 Active modes: 9
# reconstruction time: 0.031243324279785156
# relative error = 0.9129716352650312
# lKmax = 1
# constructing grids... (9, 5, 3)
# calculating infinite stress field... (9, 5, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.2692s
# Residual: 0.018826893089531612 Solving time: 0.0
# Solution: 12 Active modes: 3
# reconstruction time: 0.0
# relative error = 0.9537197346058423

# %%
# save the data to matfile
from scipy.io import savemat, whosmat

filename = '../figures/case2-result.mat'
n = 5
obj_x = np.empty((n, ), dtype=np.object)
obj_y = np.empty((n, ), dtype=np.object)
obj_label = np.empty((n, ), dtype=np.object)

plt_idx = [10, 16, 22, 26] #[4,5,6,7]
#total_time = np.array()
plt.figure()
for i in range(4):
    obj_x[i] = x3.copy()
    obj_y[i] = fx_list[plt_idx[i]][...,1,2].flatten()/mu
    obj_label[i] = r'l_{max} = %i'%mode_list[plt_idx[i]]
    plt.plot(x3, fx_list[plt_idx[i]][...,1,2].flatten()/mu, '*', label=r'$l_{max} = %i$'%mode_list[plt_idx[i]])

obj_x[-1] = x3.copy(); obj_y[-1] = analytical/mu; obj_label[-1] = 'Analytical'
savemat(filename, {'X': obj_x, 'Y': obj_y, 'label': obj_label})
print(whosmat(filename))
    
plt.plot(x3, analytical/mu, label='Analytical')
plt.legend(fontsize=14)
plt.xlabel(r"$z/r_0$", fontsize=20)
plt.ylabel(r'$\tau_{yz}/\mu$', fontsize=20)
plt.tick_params(labelsize=14)
plt.tight_layout()
plt.savefig('../figures/case2-result.png') #, dpi=1000), transparent=True)
plt.figure()
for i in plt_idx:
    sigma = fx_list[i]
    plt.semilogy(x3, -(sigma[...,1,2].flatten()-analytical.flatten())/analytical.flatten(), '*',  label=r'$l_{max} = %i$'%mode_list[i])
plt.legend()
plt.savefig('../figures/case2-result-semilog.png') #, dpi=1000))
plt.show()
# Out:
# [('X', (1, 5), 'cell'), ('Y', (1, 5), 'cell'), ('label', (1, 5), 'cell')]

# %%
plt.figure()
plt.plot(mode_list, solve_time, ':x', label='Matrix Solving')
plt.plot(mode_list, reconstruct_time, '-x', label='Solution Evaluation')
plt.xlabel('$l_{max}$', fontsize=20)
plt.ylabel('time(s)', fontsize=20)
plt.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.tight_layout()
plt.savefig('../figures/case3-time.png') #, dpi=1000), transparent=True)

error_list = []
for sigma in fx_list:
    error_list.append((-(sigma[...,1,2].flatten()-analytical.flatten())/analytical.flatten()).max())

fig, ax1 = plt.subplots()
ln1 = ax1.plot(mode_list, active_list, '-x')
ax1.set_xlabel('$l_{max}$', fontsize=20)
ax1.set_ylabel('# of modes', fontsize=20)
ax2 = ax1.twinx()
ln2 = ax2.plot(mode_list, np.array(error_list)*100, '--*g', label='relative error')
ax2.set_ylabel('relative error (%)', fontsize=20)

ax1.legend(ln1+ln2, [r'# of Non-zero $\phi^{(K)}$','Max Relative Error'], loc='right', fontsize=14)
ax1.tick_params(labelsize=14)
ax2.tick_params(labelsize=14)
plt.tight_layout()
plt.savefig('../figures/case3-err.png') #, dpi=1000), transparent=True)
plt.show()

# %%
filename = '../figures/case2-err.mat'
n = 4
obj_x = np.empty((n, ), dtype=np.object)
obj_y = np.empty((n, ), dtype=np.object)
obj_label = np.empty((n, ), dtype=np.object)
obj_x[0], obj_x[1], obj_x[2], obj_x[3] = \
    (np.array(mode_list), np.array(mode_list), np.array(mode_list), np.array(mode_list))
obj_y[0], obj_y[1], obj_y[2], obj_y[3] = \
    (np.array(error_list), np.array(solve_time), np.array(reconstruct_time), np.array(active_list))
obj_label = np.array(['Max Relative Error', 'Matrix Solving Time',\
                      'Solution Evaluation Time', 'Active Mode Number'], dtype=np.object)
savemat(filename, {'X': obj_x, 'Y': obj_y, 'label': obj_label})
print(whosmat(filename))

fig, ax1 = plt.subplots()
ln3 = ax1.plot(mode_list, np.array(error_list)*100, '--*g')
ax1.set_ylabel('relative error (%)', fontsize=20)
ax1.set_xlabel('$l_{max}$', fontsize=20)
ax2 = ax1.twinx()
ln1 = ax2.plot(mode_list, solve_time, ':x')
ln2 = ax2.plot(mode_list, reconstruct_time, '-x')
ax2.set_ylabel('time(s)', fontsize=20)

legends = ['Matrix Solving Time', 'Solution Evaluation Time', 'Max Relative Error']
ax1.legend(ln1+ln2+ln3, legends, loc='upper center', fontsize=12)
#ax2.legend()
ax1.tick_params(labelsize=14)
ax2.tick_params(labelsize=14)
plt.tight_layout()
plt.savefig('../figures/case2-err.png') #, dpi=1000), transparent=True)
plt.show()
# Out:
# [('X', (1, 4), 'cell'), ('Y', (1, 4), 'cell'), ('label', (1, 4), 'cell')]

# %%
a = 1; b = 1; mu = 1; nu = 1./3;

x3 = np.linspace(0, 3)
ts = np.linspace(3.0, 1.1, 96)*a
lKmax = 20
fx_list = []
active_list = []
solve_time = []
reconstruct_time = []
error_list = []

# load displacement modes for calculating energy
Ucmodes = loadmat(os.path.join(modepath, 'Umodes.mat'))
Tcmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
Umodes = loadmat(os.path.join(modepath, 'Umodes.mat'))
Tmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
Smodes = loadmat(os.path.join(modepath, 'Smodes.mat'))
Eel_list = []

for tvalue in ts:
    print('t/a =', tvalue/a)
    sigma, act_mode, E, tsolve, tconstruct = tauyz_ShElastic(lKmax, x3*a, tvalue, a, b, mu0=mu, nu=nu,
                                                             Tmodes=Tmodes, Smodes=Smodes, Umodes=Umodes,
                                                             Tcmodes=Tcmodes, Ucmodes=Ucmodes)
    analytical = gavazza1974(80, x3*a, [tvalue, ], mu, 0, nu, nu, a, b)
    fx_list.append(sigma)
    Eel_list.append(E)
    rel_error = ((sigma[...,1,2].flatten()-analytical.flatten())/analytical.flatten()).max()
    error_list.append(rel_error)
    print('max relative error =', rel_error)
    active_list.append(act_mode)
    solve_time.append(tsolve)
    reconstruct_time.append(tconstruct)
    
F1, Fa, F, E = willis1972(a, ts, 41, x3)
# Out:
# t/a = 3.0
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004987239837646484
# Time for loading SH modes: 0.4495s
# Residual: 6.888612598383591e-07 Solving time: 0.11063790321350098
# Solution: 1323 Active modes: 167
# reconstruction time: 0.35928988456726074
# max relative error = 6.582411405284687e-07
# t/a = 2.98
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3086s
# Residual: 7.221879716870371e-07 Solving time: 0.15396356582641602
# Solution: 1323 Active modes: 167
# reconstruction time: 0.34366464614868164
# max relative error = 6.668485806177257e-07
# t/a = 2.96
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015620708465576172
# Time for loading SH modes: 0.4457s
# Residual: 7.563437706835051e-07 Solving time: 0.12746405601501465
# Solution: 1323 Active modes: 170
# reconstruction time: 0.32713794708251953
# max relative error = 7.074197676709726e-07
# t/a = 2.94
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4182s
# Residual: 7.923259636410638e-07 Solving time: 0.16319751739501953
# Solution: 1323 Active modes: 177
# reconstruction time: 0.4008769989013672
# max relative error = 7.376128355625798e-07
# t/a = 2.92
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3487s
# Residual: 8.299750021073973e-07 Solving time: 0.17725324630737305
# Solution: 1323 Active modes: 179
# reconstruction time: 0.47872376441955566
# max relative error = 7.803330535161703e-07
# t/a = 2.9
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015618085861206055
# Time for loading SH modes: 0.2832s
# Residual: 8.379935609081497e-07 Solving time: 0.18205690383911133
# Solution: 1323 Active modes: 176
# reconstruction time: 0.4686391353607178
# max relative error = 8.662005543963085e-07
# t/a = 2.88
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015622377395629883
# Time for loading SH modes: 0.3861s
# Residual: 3.212886121640464e-07 Solving time: 0.13989949226379395
# Solution: 1323 Active modes: 184
# reconstruction time: 0.5624544620513916
# max relative error = 4.952584946703058e-07
# t/a = 2.86
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0019428730010986328
# Time for loading SH modes: 0.5007s
# Residual: 8.113506074199843e-07 Solving time: 0.15042424201965332
# Solution: 1323 Active modes: 173
# reconstruction time: 0.5879473686218262
# max relative error = 9.372492378434792e-07
# t/a = 2.84
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4504s
# Residual: 8.54865718162595e-07 Solving time: 0.1411590576171875
# Solution: 1323 Active modes: 171
# reconstruction time: 0.4759976863861084
# max relative error = 8.958710136124956e-07
# t/a = 2.82
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.01562190055847168
# Time for loading SH modes: 0.5092s
# Residual: 8.681456344538037e-07 Solving time: 0.18682241439819336
# Solution: 1323 Active modes: 171
# reconstruction time: 0.500307559967041
# max relative error = 1.0581354848614775e-06
# t/a = 2.8
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015621423721313477
# Time for loading SH modes: 0.4505s
# Residual: 8.707756948358721e-07 Solving time: 0.12128782272338867
# Solution: 1323 Active modes: 189
# reconstruction time: 0.3801286220550537
# max relative error = 8.66874453888894e-07
# t/a = 2.78
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4671s
# Residual: 8.662791228724167e-07 Solving time: 0.18483304977416992
# Solution: 1323 Active modes: 185
# reconstruction time: 0.43338584899902344
# max relative error = 9.681406553798444e-07
# t/a = 2.76
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004987001419067383
# Time for loading SH modes: 0.4801s
# Residual: 4.411346251187999e-07 Solving time: 0.14937067031860352
# Solution: 1323 Active modes: 203
# reconstruction time: 0.5152263641357422
# max relative error = 7.069542605072663e-07
# t/a = 2.74
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989458084106445
# Time for loading SH modes: 0.3379s
# Residual: 4.5910369546487057e-07 Solving time: 0.15479707717895508
# Solution: 1323 Active modes: 197
# reconstruction time: 0.4787752628326416
# max relative error = 7.464437210091286e-07
# t/a = 2.7199999999999998
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004986763000488281
# Time for loading SH modes: 0.4083s
# Residual: 4.862960386834221e-07 Solving time: 0.2980527877807617
# Solution: 1323 Active modes: 202
# reconstruction time: 0.8260006904602051
# max relative error = 7.919640540614358e-07
# t/a = 2.7
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015620231628417969
# Time for loading SH modes: 0.3611s
# Residual: 5.163125124141653e-07 Solving time: 0.1691277027130127
# Solution: 1323 Active modes: 203
# reconstruction time: 0.46521997451782227
# max relative error = 8.477801458451503e-07
# t/a = 2.68
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.016433238983154297
# Time for loading SH modes: 0.3989s
# Residual: 5.457995121926226e-07 Solving time: 0.1730186939239502
# Solution: 1323 Active modes: 208
# reconstruction time: 0.6849958896636963
# max relative error = 8.937535557975018e-07
# t/a = 2.66
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4137s
# Residual: 5.747223728944721e-07 Solving time: 0.12112236022949219
# Solution: 1323 Active modes: 205
# reconstruction time: 0.6624529361724854
# max relative error = 9.483247166607981e-07
# t/a = 2.64
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.01562047004699707
# Time for loading SH modes: 0.3663s
# Residual: 6.091051309369536e-07 Solving time: 0.24992823600769043
# Solution: 1323 Active modes: 206
# reconstruction time: 0.5721139907836914
# max relative error = 1.0023503069844707e-06
# t/a = 2.62
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4819s
# Residual: 6.505047399716313e-07 Solving time: 0.2067406177520752
# Solution: 1323 Active modes: 214
# reconstruction time: 0.5712563991546631
# max relative error = 1.059476081035616e-06
# t/a = 2.6
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.016539335250854492
# Time for loading SH modes: 0.3340s
# Residual: 6.912878993048054e-07 Solving time: 0.15038037300109863
# Solution: 1323 Active modes: 211
# reconstruction time: 0.5366556644439697
# max relative error = 1.1341495942601357e-06
# t/a = 2.58
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4339s
# Residual: 7.302759861054583e-07 Solving time: 0.13382983207702637
# Solution: 1323 Active modes: 214
# reconstruction time: 0.523587703704834
# max relative error = 1.1971923052740233e-06
# t/a = 2.56
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.019180774688720703
# Time for loading SH modes: 0.4807s
# Residual: 7.764480406454595e-07 Solving time: 0.21768999099731445
# Solution: 1323 Active modes: 216
# reconstruction time: 0.7821111679077148
# max relative error = 1.259369695336579e-06
# t/a = 2.54
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4842s
# Residual: 8.29354527811191e-07 Solving time: 0.20030879974365234
# Solution: 1323 Active modes: 219
# reconstruction time: 0.8232433795928955
# max relative error = 1.3380798262015308e-06
# t/a = 2.52
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.00498652458190918
# Time for loading SH modes: 0.4719s
# Residual: 8.828756064620017e-07 Solving time: 0.16626501083374023
# Solution: 1323 Active modes: 218
# reconstruction time: 0.5842270851135254
# max relative error = 1.417556382760092e-06
# t/a = 2.5
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.016568660736083984
# Time for loading SH modes: 0.4167s
# Residual: 9.414065007333796e-07 Solving time: 0.1201474666595459
# Solution: 1323 Active modes: 216
# reconstruction time: 0.7635574340820312
# max relative error = 1.4901635471627916e-06
# t/a = 2.48
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0059850215911865234
# Time for loading SH modes: 0.4097s
# Residual: 1.0062781612337604e-06 Solving time: 0.21529221534729004
# Solution: 1323 Active modes: 218
# reconstruction time: 0.5655381679534912
# max relative error = 1.5812048434692822e-06
# t/a = 2.46
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015621423721313477
# Time for loading SH modes: 0.4436s
# Residual: 1.037607678918941e-06 Solving time: 0.13360190391540527
# Solution: 1323 Active modes: 231
# reconstruction time: 0.5505435466766357
# max relative error = 1.5989971000085882e-06
# t/a = 2.44
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4866s
# Residual: 1.0413820509926938e-06 Solving time: 0.19830536842346191
# Solution: 1323 Active modes: 245
# reconstruction time: 0.6167426109313965
# max relative error = 1.6171339522504912e-06
# t/a = 2.42
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.017624378204345703
# Time for loading SH modes: 0.3673s
# Residual: 6.261896870730759e-07 Solving time: 0.21662092208862305
# Solution: 1323 Active modes: 213
# reconstruction time: 0.7172119617462158
# max relative error = 1.347692375406529e-06
# t/a = 2.4
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015622138977050781
# Time for loading SH modes: 0.4794s
# Residual: 6.658270482208413e-07 Solving time: 0.24500393867492676
# Solution: 1323 Active modes: 212
# reconstruction time: 0.5175981521606445
# max relative error = 1.4405553572337965e-06
# t/a = 2.38
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015630483627319336
# Time for loading SH modes: 0.3679s
# Residual: 7.164253196835857e-07 Solving time: 0.23715877532958984
# Solution: 1323 Active modes: 214
# reconstruction time: 0.684795618057251
# max relative error = 1.5424304224639763e-06
# t/a = 2.36
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.002062082290649414
# Time for loading SH modes: 0.4483s
# Residual: 7.625688579159379e-07 Solving time: 0.20041227340698242
# Solution: 1323 Active modes: 212
# reconstruction time: 0.851055383682251
# max relative error = 1.6463613723568909e-06
# t/a = 2.34
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4574s
# Residual: 8.177206512045937e-07 Solving time: 0.21393299102783203
# Solution: 1323 Active modes: 213
# reconstruction time: 0.868192195892334
# max relative error = 1.7580701496279788e-06
# t/a = 2.32
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015620708465576172
# Time for loading SH modes: 0.4819s
# Residual: 8.793355930157659e-07 Solving time: 0.21741819381713867
# Solution: 1323 Active modes: 215
# reconstruction time: 0.6915814876556396
# max relative error = 1.8760014882926942e-06
# t/a = 2.3
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.001631021499633789
# Time for loading SH modes: 0.3430s
# Residual: 9.45010544002235e-07 Solving time: 0.1572554111480713
# Solution: 1323 Active modes: 214
# reconstruction time: 0.3816096782684326
# max relative error = 1.9990592238385216e-06
# t/a = 2.2800000000000002
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003988981246948242
# Time for loading SH modes: 0.4993s
# Residual: 1.0184892383936077e-06 Solving time: 0.17971253395080566
# Solution: 1323 Active modes: 215
# reconstruction time: 0.7688612937927246
# max relative error = 2.1279893970412308e-06
# t/a = 2.26
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.5860s
# Residual: 1.094898197197296e-06 Solving time: 0.2860722541809082
# Solution: 1323 Active modes: 216
# reconstruction time: 0.5911741256713867
# max relative error = 2.2624428249051437e-06
# t/a = 2.24
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0059850215911865234
# Time for loading SH modes: 0.3469s
# Residual: 8.584067908821925e-07 Solving time: 0.21202945709228516
# Solution: 1323 Active modes: 237
# reconstruction time: 0.4395017623901367
# max relative error = 1.9423549529082754e-06
# t/a = 2.2199999999999998
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015620231628417969
# Time for loading SH modes: 0.4184s
# Residual: 8.387726973873056e-07 Solving time: 0.13237738609313965
# Solution: 1323 Active modes: 245
# reconstruction time: 0.46984267234802246
# max relative error = 1.985768769364023e-06
# t/a = 2.2
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.007978439331054688
# Time for loading SH modes: 0.4834s
# Residual: 7.153825460245189e-07 Solving time: 0.16901159286499023
# Solution: 1323 Active modes: 218
# reconstruction time: 0.885730504989624
# max relative error = 1.9636526446140723e-06
# t/a = 2.1799999999999997
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.043154239654541016
# Time for loading SH modes: 0.4329s
# Residual: 9.745196891610177e-07 Solving time: 0.15539956092834473
# Solution: 1323 Active modes: 254
# reconstruction time: 0.6753463745117188
# max relative error = 2.2754313637550018e-06
# t/a = 2.16
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.007675647735595703
# Time for loading SH modes: 0.3217s
# Residual: 8.454494922013936e-07 Solving time: 0.1415565013885498
# Solution: 1323 Active modes: 224
# reconstruction time: 0.8416695594787598
# max relative error = 2.2818936205406254e-06
# t/a = 2.14
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0069789886474609375
# Time for loading SH modes: 0.3246s
# Residual: 9.720154284612347e-07 Solving time: 0.1025075912475586
# Solution: 1323 Active modes: 240
# reconstruction time: 0.4701111316680908
# max relative error = 2.4809537346159028e-06
# t/a = 2.12
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004108905792236328
# Time for loading SH modes: 0.4663s
# Residual: 9.544251860229902e-07 Solving time: 0.20156478881835938
# Solution: 1323 Active modes: 232
# reconstruction time: 0.5808684825897217
# max relative error = 2.6085086964452555e-06
# t/a = 2.1
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0050160884857177734
# Time for loading SH modes: 0.3955s
# Residual: 1.0250808159410865e-06 Solving time: 0.17767071723937988
# Solution: 1323 Active modes: 222
# reconstruction time: 0.7595937252044678
# max relative error = 2.784012716468259e-06
# t/a = 2.08
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.010703325271606445
# Time for loading SH modes: 0.3670s
# Residual: 1.1049430041317923e-06 Solving time: 0.19530773162841797
# Solution: 1323 Active modes: 222
# reconstruction time: 0.5086386203765869
# max relative error = 2.9705382257131927e-06
# t/a = 2.06
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.00797724723815918
# Time for loading SH modes: 0.2870s
# Residual: 1.1937090997985913e-06 Solving time: 0.182511568069458
# Solution: 1323 Active modes: 222
# reconstruction time: 0.44880032539367676
# max relative error = 3.170863088816957e-06
# t/a = 2.04
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.005983829498291016
# Time for loading SH modes: 0.5355s
# Residual: 1.2919888274629964e-06 Solving time: 0.11568999290466309
# Solution: 1323 Active modes: 225
# reconstruction time: 0.595203161239624
# max relative error = 3.373462540276504e-06
# t/a = 2.02
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989219665527344
# Time for loading SH modes: 0.4254s
# Residual: 1.215299687287963e-06 Solving time: 0.1381082534790039
# Solution: 1323 Active modes: 248
# reconstruction time: 0.6267580986022949
# max relative error = 3.210361699730465e-06
# t/a = 2.0
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3524s
# Residual: 7.926003250766451e-07 Solving time: 0.2856578826904297
# Solution: 1323 Active modes: 228
# reconstruction time: 0.6825380325317383
# max relative error = 2.670608513823403e-06
# t/a = 1.98
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.00152587890625
# Time for loading SH modes: 0.4332s
# Residual: 8.549789088628052e-07 Solving time: 0.21767950057983398
# Solution: 1323 Active modes: 228
# reconstruction time: 0.43810009956359863
# max relative error = 2.887179945249561e-06
# t/a = 1.96
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.00771784782409668
# Time for loading SH modes: 0.4804s
# Residual: 1.1788773483847298e-06 Solving time: 0.17241811752319336
# Solution: 1323 Active modes: 276
# reconstruction time: 0.6163737773895264
# max relative error = 3.3659445410108115e-06
# t/a = 1.94
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3719s
# Residual: 9.939400699379646e-07 Solving time: 0.1848597526550293
# Solution: 1323 Active modes: 233
# reconstruction time: 0.47354722023010254
# max relative error = 3.3489719075476948e-06
# t/a = 1.92
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.2556s
# Residual: 1.0773807499566606e-06 Solving time: 0.17440199851989746
# Solution: 1323 Active modes: 231
# reconstruction time: 0.3178365230560303
# max relative error = 3.5980362044621862e-06
# t/a = 1.9
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004988193511962891
# Time for loading SH modes: 0.5035s
# Residual: 1.1631199299705103e-06 Solving time: 0.2622857093811035
# Solution: 1323 Active modes: 229
# reconstruction time: 0.6729738712310791
# max relative error = 3.853046314747574e-06
# t/a = 1.88
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0049860477447509766
# Time for loading SH modes: 0.4544s
# Residual: 1.2672594133887993e-06 Solving time: 0.1460585594177246
# Solution: 1323 Active modes: 233
# reconstruction time: 0.597283124923706
# max relative error = 4.1209066895524635e-06
# t/a = 1.8599999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3001s
# Residual: 1.3701461899860319e-06 Solving time: 0.1510298252105713
# Solution: 1323 Active modes: 225
# reconstruction time: 0.43801164627075195
# max relative error = 4.388951589994389e-06
# t/a = 1.84
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3755s
# Residual: 1.338094949856099e-06 Solving time: 0.1530294418334961
# Solution: 1323 Active modes: 238
# reconstruction time: 0.5494015216827393
# max relative error = 4.284732467043634e-06
# t/a = 1.82
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4140s
# Residual: 1.4721502900462134e-06 Solving time: 0.15621399879455566
# Solution: 1323 Active modes: 238
# reconstruction time: 0.6811959743499756
# max relative error = 4.573144234254345e-06
# t/a = 1.8
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004986286163330078
# Time for loading SH modes: 0.4010s
# Residual: 1.5312920782969773e-06 Solving time: 0.14818572998046875
# Solution: 1323 Active modes: 240
# reconstruction time: 0.4830765724182129
# max relative error = 4.714645617609179e-06
# t/a = 1.78
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989696502685547
# Time for loading SH modes: 0.5074s
# Residual: 1.4194932338413731e-06 Solving time: 0.3731048107147217
# Solution: 1323 Active modes: 255
# reconstruction time: 0.9217715263366699
# max relative error = 4.352515295684214e-06
# t/a = 1.76
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0049877166748046875
# Time for loading SH modes: 0.3831s
# Residual: 1.5594948686479047e-06 Solving time: 0.2198808193206787
# Solution: 1323 Active modes: 273
# reconstruction time: 0.5931234359741211
# max relative error = 4.618634602437689e-06
# t/a = 1.74
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.5099s
# Residual: 1.4433135556042707e-06 Solving time: 0.11842799186706543
# Solution: 1323 Active modes: 231
# reconstruction time: 0.6596972942352295
# max relative error = 4.455691364275374e-06
# t/a = 1.72
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015619516372680664
# Time for loading SH modes: 0.3935s
# Residual: 1.616207165581718e-06 Solving time: 0.18891215324401855
# Solution: 1323 Active modes: 239
# reconstruction time: 0.5806400775909424
# max relative error = 4.498435082638232e-06
# t/a = 1.7
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.006373167037963867
# Time for loading SH modes: 0.3705s
# Residual: 1.6740767681475506e-06 Solving time: 0.1689929962158203
# Solution: 1323 Active modes: 258
# reconstruction time: 0.734187126159668
# max relative error = 4.044448519375903e-06
# t/a = 1.68
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3472s
# Residual: 1.7019533629182447e-06 Solving time: 0.1857290267944336
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6530501842498779
# max relative error = 1.055679106997012e-06
# t/a = 1.66
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4730s
# Residual: 2.1150933478938353e-06 Solving time: 0.3900415897369385
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6721251010894775
# max relative error = 2.5782259721584303e-08
# t/a = 1.64
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.005990505218505859
# Time for loading SH modes: 0.3968s
# Residual: 2.6875328991419e-06 Solving time: 0.31900978088378906
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6293601989746094
# max relative error = 3.850925948889872e-08
# t/a = 1.6199999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4772s
# Residual: 3.425070570572357e-06 Solving time: 0.3172314167022705
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6962029933929443
# max relative error = 5.767273021576579e-08
# t/a = 1.5999999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4272s
# Residual: 4.3782434057139874e-06 Solving time: 0.21646714210510254
# Solution: 1323 Active modes: 222
# reconstruction time: 0.4800238609313965
# max relative error = 8.658526555981232e-08
# t/a = 1.58
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3337s
# Residual: 5.61393915450231e-06 Solving time: 0.3445925712585449
# Solution: 1323 Active modes: 222
# reconstruction time: 0.6463973522186279
# max relative error = 1.3027722842563242e-07
# t/a = 1.56
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4338s
# Residual: 7.220963440138606e-06 Solving time: 0.30390095710754395
# Solution: 1323 Active modes: 224
# reconstruction time: 0.7145974636077881
# max relative error = 1.9637144827581184e-07
# t/a = 1.54
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989458084106445
# Time for loading SH modes: 0.3838s
# Residual: 9.31759230106223e-06 Solving time: 0.2792942523956299
# Solution: 1323 Active modes: 230
# reconstruction time: 0.7118806838989258
# max relative error = 2.963716969548448e-07
# t/a = 1.52
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.01664113998413086
# Time for loading SH modes: 0.4507s
# Residual: 1.2061847647326159e-05 Solving time: 0.23686981201171875
# Solution: 1323 Active modes: 232
# reconstruction time: 0.6848654747009277
# max relative error = 4.4766294320906706e-07
# t/a = 1.5
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004987955093383789
# Time for loading SH modes: 0.3196s
# Residual: 1.5665516687798676e-05 Solving time: 0.32256126403808594
# Solution: 1323 Active modes: 242
# reconstruction time: 0.6694974899291992
# max relative error = 6.750009574987269e-07
# t/a = 1.48
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.005982875823974609
# Time for loading SH modes: 0.4260s
# Residual: 2.0413331657781085e-05 Solving time: 0.26596856117248535
# Solution: 1323 Active modes: 254
# reconstruction time: 0.6473865509033203
# max relative error = 1.017750798184988e-06
# t/a = 1.46
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4511s
# Residual: 2.6689277810319984e-05 Solving time: 0.49730467796325684
# Solution: 1323 Active modes: 268
# reconstruction time: 0.900700569152832
# max relative error = 1.530440084447013e-06
# t/a = 1.44
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015619039535522461
# Time for loading SH modes: 0.3477s
# Residual: 3.5012767896348216e-05 Solving time: 0.15133905410766602
# Solution: 1323 Active modes: 288
# reconstruction time: 0.5705654621124268
# max relative error = 2.28701052314363e-06
# t/a = 1.42
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3429s
# Residual: 4.608849672632351e-05 Solving time: 0.22365069389343262
# Solution: 1323 Active modes: 322
# reconstruction time: 0.4867115020751953
# max relative error = 3.391573594231707e-06
# t/a = 1.4
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3248s
# Residual: 6.087528946399668e-05 Solving time: 0.17923545837402344
# Solution: 1323 Active modes: 358
# reconstruction time: 0.4632105827331543
# max relative error = 4.962544258080041e-06
# t/a = 1.38
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.4785s
# Residual: 8.068134596151514e-05 Solving time: 0.23009228706359863
# Solution: 1323 Active modes: 384
# reconstruction time: 0.5615265369415283
# max relative error = 7.1208977109781336e-06
# t/a = 1.3599999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004961490631103516
# Time for loading SH modes: 0.3843s
# Residual: 0.00010729618288036657 Solving time: 0.23845481872558594
# Solution: 1323 Active modes: 427
# reconstruction time: 0.6309025287628174
# max relative error = 9.907025619667444e-06
# t/a = 1.3399999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0007877349853515625
# Time for loading SH modes: 0.7478s
# Residual: 0.00014317358220221314 Solving time: 0.20343232154846191
# Solution: 1323 Active modes: 487
# reconstruction time: 0.903296709060669
# max relative error = 1.3086285197072465e-05
# t/a = 1.32
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0049860477447509766
# Time for loading SH modes: 0.4891s
# Residual: 0.00019168535708431446 Solving time: 0.18849658966064453
# Solution: 1323 Active modes: 532
# reconstruction time: 0.5991425514221191
# max relative error = 1.5703956736426904e-05
# t/a = 1.3
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.005223751068115234
# Time for loading SH modes: 0.3839s
# Residual: 0.0002574732380289389 Solving time: 0.2988729476928711
# Solution: 1323 Active modes: 577
# reconstruction time: 0.7235894203186035
# max relative error = 1.4935910849594039e-05
# t/a = 1.28
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3293s
# Residual: 0.0003469362737654384 Solving time: 0.1856861114501953
# Solution: 1323 Active modes: 610
# reconstruction time: 0.5116314888000488
# max relative error = 3.7964491555206283e-06
# t/a = 1.26
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015623331069946289
# Time for loading SH modes: 0.3481s
# Residual: 0.00046890456370243485 Solving time: 0.19962501525878906
# Solution: 1323 Active modes: 622
# reconstruction time: 0.855186939239502
# max relative error = -3.7970277451717867e-06
# t/a = 1.24
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015621185302734375
# Time for loading SH modes: 0.3454s
# Residual: 0.0006355677841714341 Solving time: 0.20105242729187012
# Solution: 1323 Active modes: 628
# reconstruction time: 0.5447816848754883
# max relative error = -7.283935901702384e-06
# t/a = 1.22
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.3479s
# Residual: 0.0008637501173234717 Solving time: 0.22194504737854004
# Solution: 1323 Active modes: 628
# reconstruction time: 0.5935087203979492
# max relative error = -1.4054652639746465e-05
# t/a = 1.2
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.015621423721313477
# Time for loading SH modes: 0.2273s
# Residual: 0.0011766544816528698 Solving time: 0.17684173583984375
# Solution: 1323 Active modes: 628
# reconstruction time: 0.4258401393890381
# max relative error = -2.725609574091415e-05
# t/a = 1.18
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.006981849670410156
# Time for loading SH modes: 0.3238s
# Residual: 0.0016062459750272842 Solving time: 0.24090790748596191
# Solution: 1323 Active modes: 628
# reconstruction time: 1.0802721977233887
# max relative error = -5.306518175854719e-05
# t/a = 1.16
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003986358642578125
# Time for loading SH modes: 0.2753s
# Residual: 0.002196531616025542 Solving time: 0.2668933868408203
# Solution: 1323 Active modes: 628
# reconstruction time: 0.47769594192504883
# max relative error = -0.00010356492031109271
# t/a = 1.14
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.004987478256225586
# Time for loading SH modes: 0.5143s
# Residual: 0.0030081999519249686 Solving time: 0.4321589469909668
# Solution: 1323 Active modes: 630
# reconstruction time: 0.8975660800933838
# max relative error = -0.0002021806970015423
# t/a = 1.1199999999999999
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989219665527344
# Time for loading SH modes: 0.1695s
# Residual: 0.004125661175816189 Solving time: 0.04788351058959961
# Solution: 1323 Active modes: 630
# reconstruction time: 0.17082929611206055
# max relative error = -0.00039362241900105054
# t/a = 1.1
# constructing grids... (47, 24, 3)
# calculating infinite stress field... (47, 24, 3, 3)
# setting up the boundary condition... 0.003989696502685547
# Time for loading SH modes: 0.1217s
# Residual: 0.005669270285696263 Solving time: 0.06826543807983398
# Solution: 1323 Active modes: 630
# reconstruction time: 0.1526355743408203
# max relative error = -0.0007610160380047291

# %%
filename = '../figures/case2-result-ts.mat'
print(len(fx_list))
n = 3
obj_x = np.empty((n, ), dtype=np.object)
obj_y = np.empty((n, ), dtype=np.object)
obj_ya= np.empty((n, ), dtype=np.object)
obj_label = np.empty((n, ), dtype=np.object)

plt.figure()
plotlist = [75, 85, 90] #50+np.arange(0, n, dtype=np.int)*40
colors = ['C1', 'C2', 'C3']
for i in range(n):
    obj_x[i] = x3.copy()
    obj_y[i] = fx_list[plotlist[i]][:,:,:,1,2].flatten()
    obj_ya[i]= gavazza1974(80, x3*a, [ts[plotlist[i]], ], mu, 0, nu, nu, a, b).flatten()
    obj_label[i] = '$t/r_0$ = '+str(ts[plotlist[i]]/a)
    plt.plot(x3, fx_list[plotlist[i]][:,:,:,1,2].flatten(), 'o'+colors[i])
    plt.plot(x3, obj_ya[i], colors[i])
legs_t = ['$t/r_0$ = '+str(ts[plotlist[i]]/a) for i in range(n)]
plt.legend(legs_t)
#plt.ylim(0, 3)
plt.xlabel(r'$z/r_0$')
plt.ylabel(r'$\tau_{yz}/\mu$')
#plt.savefig('../figures/case2-result-ts.png') #, dpi=1000))

savemat(filename, {'X': obj_x, 'Y': obj_y, 'YA':obj_ya, 'label': obj_label})
print(whosmat(filename))

'''
filename = '../figures/case2-err-ts.mat'
n = 2
obj_x = np.empty((n, ), dtype=np.object)
obj_y = np.empty((n, ), dtype=np.object)
obj_x[0], obj_x[1] = (ts/a, ts/a)
obj_y[0], obj_y[1] = (active_list, np.absolute(error_list))
obj_label = np.array(['Number of Non-zero SH Modes', 'Max Relative Error'], dtype=np.object)
#savemat(filename, {'X': obj_x, 'Y': obj_y, 'label': obj_label})
print(whosmat(filename))
'''

Easym = -mu*b**2*a**3/ts**2 *5/np.pi/16
filename = '../figures/case2-E-ts.mat'
n = 3
obj_x = np.empty((n, ), dtype=np.object)
obj_y = np.empty((n, ), dtype=np.object)
obj_x[0], obj_x[1], obj_x[2] = (ts/a, ts/a, ts/a)
obj_y[0], obj_y[1], obj_y[2] = (Eel_list, Easym, E)
obj_label = np.array(['E^{img}', 'E^{asy}', 'E^{ana}'], dtype=np.object)
savemat(filename, {'X': obj_x, 'Y': obj_y, 'label': obj_label})
print(whosmat(filename))

fig, ax1 = plt.subplots()
ln1 = ax1.plot(ts/a, active_list, '-x')
ax1.set_ylim(0, 2000)
ax1.set_xlabel('$t/r_0$')
ax1.set_ylabel('# of modes')
ax2 = ax1.twinx()
ln2 = ax2.semilogy(ts/a, np.absolute(error_list), '--*g', label='relative error')
ax2.set_ylabel('relative error')
ax1.legend(ln1+ln2, ['# of non-zero SH modes','max relative error'],loc='right')
#plt.savefig('../figures/case2-error-ts.png') #, dpi=1000))
plt.show()
# Out:
# 96
# [('X', (1, 3), 'cell'), ('Y', (1, 3), 'cell'), ('YA', (1, 3), 'cell'), ('label', (1, 3), 'cell')]
# [('X', (1, 3), 'cell'), ('Y', (1, 3), 'cell'), ('label', (1, 3), 'cell')]

# %%
fx = -np.stack(fx_list, axis=0)[...,1,2].squeeze()
print(fx.shape, F1.shape)
plt.plot(ts, fx[:, 0].T, '*')
plt.plot(ts, F1[:, 0])
plt.xlabel('$t/r_0$')
plt.ylabel('$f(z=0)a/\mu b^2$')
plt.legend(['ShElastic', 'Willis'])
plt.show()
# Out:
# (96, 50) (96, 50)

# %%
Eimg = np.array(Eel_list)
plt.plot(ts, Eimg, '*')
plt.plot(ts, E)
plt.plot(ts, -1/ts**2 *5/np.pi/16)
plt.xlabel('$t/r_0$')
plt.ylabel('$E/\mu b^2a$')
plt.legend(['ShElastic', 'Willis', 'asymptotic'], loc='lower right')
plt.show()
#print(np.abs((Eimg/E-1)))
#print(np.abs((Easym/E-1))[-40])
#print(Easym.shape)

# %% [markdown]
# ## Test the calculation time as a function of the \# of nodes to evaluate

# %%
a = 1; b = 1; t = 1.2;
mu = 1; nu = 0.25;

lKmax = 16
np_list = (10**(np.linspace(0, 4, 13))).astype(np.int)
fx_list = []
active_list = []
solve_time = []
reconstruct_time = []
error_list = []
shtype = 'irr'
Tmodes = loadmat(os.path.join(modepath, 'Tmodes.mat'))
Smodes = loadmat(os.path.join(modepath, 'Smodes.mat'))

for npoints in np_list:
    print('npoints =', npoints)
    x3 = np.linspace(-3, 3, npoints)
    analytical = gavazza1974(30, x3*a, [t, ], mu, 0, nu, nu, a, b)
    
    sigma, act_mode, tsolve, tconstruct = tauyz_ShElastic(lKmax, x3, t, a, b, mu0=mu, nu=nu, Tmodes=Tmodes, Smodes=Smodes)
    err = np.absolute((sigma[...,1,2].flatten()-analytical.flatten())/analytical.flatten()).max()
    print('relative error =', err)
    error_list.append(err)
    fx_list.append(sigma)
    active_list.append(act_mode)
    solve_time.append(tsolve)
    reconstruct_time.append(tconstruct)
# Out:
# npoints = 1
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0029921531677246094
# Time for loading SH modes: 0.1346s
# Residual: 0.002754586380377301 Solving time: 0.01642584800720215
# Solution: 867 Active modes: 408
# reconstruction time: 0.05644106864929199
# relative error = 0.0001367327730218528
# npoints = 2
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.008310317993164062
# Time for loading SH modes: 0.1951s
# Residual: 0.002754586380377301 Solving time: 0.050782203674316406
# Solution: 867 Active modes: 408
# reconstruction time: 0.06501650810241699
# relative error = 0.0001367327730218528
# npoints = 4
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1312s
# Residual: 0.002754586380377301 Solving time: 0.03650236129760742
# Solution: 867 Active modes: 408
# reconstruction time: 0.06870627403259277
# relative error = 0.0005535104077436892
# npoints = 10
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1432s
# Residual: 0.002754586380377301 Solving time: 0.03743338584899902
# Solution: 867 Active modes: 408
# reconstruction time: 0.07643747329711914
# relative error = 0.006885573825482664
# npoints = 21
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0029807090759277344
# Time for loading SH modes: 0.1389s
# Residual: 0.002754586380377301 Solving time: 0.041329145431518555
# Solution: 867 Active modes: 408
# reconstruction time: 0.08298063278198242
# relative error = 0.006911068347244527
# npoints = 46
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1180s
# Residual: 0.002754586380377301 Solving time: 0.037233591079711914
# Solution: 867 Active modes: 408
# reconstruction time: 0.09771323204040527
# relative error = 0.006885573825482664
# npoints = 100
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1169s
# Residual: 0.002754586380377301 Solving time: 0.0166933536529541
# Solution: 867 Active modes: 408
# reconstruction time: 0.14986896514892578
# relative error = 0.006885573825482664
# npoints = 215
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.00045180320739746094
# Time for loading SH modes: 0.1003s
# Residual: 0.002754586380377301 Solving time: 0.04687356948852539
# Solution: 867 Active modes: 408
# reconstruction time: 0.26680922508239746
# relative error = 0.006921521350905105
# npoints = 464
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1170s
# Residual: 0.002754586380377301 Solving time: 0.016792774200439453
# Solution: 867 Active modes: 408
# reconstruction time: 0.5172779560089111
# relative error = 0.0069199036015905125
# npoints = 1000
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1004s
# Residual: 0.002754586380377301 Solving time: 0.03324246406555176
# Solution: 867 Active modes: 408
# reconstruction time: 1.0176432132720947
# relative error = 0.00692195653377426
# npoints = 2154
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1687s
# Residual: 0.002754586380377301 Solving time: 0.03735828399658203
# Solution: 867 Active modes: 408
# reconstruction time: 2.2678892612457275
# relative error = 0.006922377345223156
# npoints = 4641
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1264s
# Residual: 0.002754586380377301 Solving time: 0.03402519226074219
# Solution: 867 Active modes: 408
# reconstruction time: 4.852895975112915
# relative error = 0.006922475066487625
# npoints = 10000
# constructing grids... (39, 20, 3)
# calculating infinite stress field... (39, 20, 3, 3)
# setting up the boundary condition... 0.0
# Time for loading SH modes: 0.1165s
# Residual: 0.002754586380377301 Solving time: 0.01680302619934082
# Solution: 867 Active modes: 408
# reconstruction time: 10.366353511810303
# relative error = 0.006922477525129792

# %%
np_list = (10**(np.linspace(0, 4, 13))).astype(np.int)
plt.figure()
plt.plot(np_list, solve_time, ':x', label='matrix solve time')
plt.plot(np_list, reconstruct_time, '-x', label='solution evaluation time')
plt.xlabel('# of points for evaluation')
plt.ylabel('time(s)')
plt.legend()
#plt.savefig('../figures/case2-time.png')

print('relative error:', np.max(error_list))
plt.show()
# Out:
# relative error: 0.006922477525129792
