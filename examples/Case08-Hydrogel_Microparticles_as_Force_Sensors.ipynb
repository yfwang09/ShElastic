# %% [markdown]
# # Hydrogel-Cell Interaction Test Case
#
# In this case, we load the deformed shape of the spherical hydrogel as shown in the next few cells.

# %%
import numpy as np
import scipy as sp
import scipy.sparse as spm
from scipy.sparse.linalg import lsqr, spsolve
from scipy.interpolate import RectBivariateSpline
from scipy.optimize import minimize
from scipy.io import loadmat, savemat

import matplotlib.pyplot as plt
from matplotlib import cm, colors
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import sys, time, os.path
from itertools import permutations
import pyshtools

sys.path.append('..')
from shelastic.shutil import SphCoord_to_CartCoord, CartCoord_to_SphCoord, GLQCartCoord
from shelastic.shutil import SHCilmToVector, SHVectorToCilm, SHVec2mesh, SHmesh2Vec
from shelastic.shutil import TransMat, l_coeffs, m_coeffs, LM_list, lmk2K, K2lmk
from shelastic.shbv import generate_submat, Uvec2Tvec, Tvec2Uvec
from shelastic.shvis  import plotfv, vismesh, visSHVec, visSH3d
from shelastic.sphere_utils import loadCoeffs, arbitrary_force, Ur_interp
from shelastic.sphere_utils import usurf2umesh, dumesh_dus, usurf2vec
from shelastic.sphere_utils import Tvec2Tres, usurf2dr2, calculateTfv, genSmat, genLmat, grad_usurf2dr2

# %% [markdown]
# ## Input information

# %%
############################# change inputs here #################################
# Data file name
datadir = '../testdata'
smoothed = 'smoothed'
dilated = '_1um_dilated'
#dilated = '_softedge'
shapename = 'Particle01'
datafile = os.path.join(datadir, shapename+'_Coordinates_Cart_'+smoothed+'.csv')
connfile = os.path.join(datadir, shapename+'_Connectivity.csv')
maskfile = os.path.join(datadir, shapename+'_Mask'+dilated+'.csv')
print('Cartesian coordinates: %s'%datafile)
print('Node connectivity: %s'%connfile)
print('Traction-free mask: %s'%maskfile)

# Material properties
mu0 = 1300/3; nu0 = 0.499;

# Spherical Harmonics Analysis Settings
lJmax = 20; lKmax = lJmax; lmax_plot = 60;

# initial guess settings
init_guess_type = 'ur-only' #'ur-only' or 'true'

# regularizations
mybeta  = 1     # traction residual magnitude (alpha in the paper)
mygamma = 1     # anti-aliasing parameter     (beta  in the paper)

# program switches
plot_figure = True # False
myord = 1; # myord: p-norm order (1-mean value)

# minimization settings
N_period = 2000
maxiter_per_period = 5
CG_gtol = 1e-5
eps = 1e-5               # for jacobian

minimizer = 'CG'
minimizer_config = {'maxiter': maxiter_per_period, 'disp': True, 'gtol': CG_gtol}

# dump files for minimization
savename = shapename+('_b%.0e'%(mybeta))+('_lmax%d'%lJmax)+smoothed+dilated+'_g%.0e'%mygamma

# settings for loading \hat{U}, \hat{T} coefficients
Cmat, Dmat = loadCoeffs(mu0, nu0, lJmax, 'reg')
# Out:
# Cartesian coordinates: ../testdata\Particle01_Coordinates_Cart_smoothed.csv
# Node connectivity: ../testdata\Particle01_Connectivity.csv
# Traction-free mask: ../testdata\Particle01_Mask_1um_dilated.csv
# Integrating modes to a matrix
# 1323 1323
# Integrating modes to a matrix
# 1323 1323

# %% [markdown]
# ## Load the geometry
#
# Visualize the traction-free boundary

# %%
#### load the geometry ####
# Vs, Vp: list of nodes (nV, trivial), coordinates of the nodes (nVx3)
# Es, Ep: list of edges (nEx2), list of points on the edges (nEx2x3)
# Fs, Fp: list of facets (nFx3), list of points on the facets (nFx3x3)
# Tfv: traction free boundary map of the node list
# Tfe: traction free boundary map of the edge list
# Tff: traction free boundary map of the face list
# Tf_diluted: diluted traction free boundary map

data = np.genfromtxt(datafile, delimiter=',')
conn = np.genfromtxt(connfile, delimiter=',', dtype=np.int)
if dilated == '_softedge':
    masktype = np.float
else:
    masktype = np.int
if shapename == 'Shape4':
    mask = np.zeros_like(data[:,0]).astype(masktype)
else:
    mask = np.genfromtxt(maskfile, dtype=masktype)
print('data, connectivity:', data.shape, conn.shape)

Fs = conn - 1
Np = data.shape[0]
Vs = np.arange(Np)
edge_conn = spm.lil_matrix((Np, Np), dtype=bool)
for i, j in permutations(range(3), 2):
    edge_conn[Fs[:, i], Fs[:, j]] = True
Es = spm.triu(edge_conn).tocoo()
Es = np.vstack([Es.row, Es.col]).T
print('id of nodes, edges, facets:', Vs.shape, Es.shape, Fs.shape)
Vp = data[..., :3]
Ep = Vp[Es, :]; Fp = Vp[Fs, :];
print('coord of nodes, edges, facets:', Vp.shape, Ep.shape, Fp.shape)

if dilated == '_softedge':
    Tfv = (mask > 0.5)
else:
    Tfv = mask.astype(np.bool)

#### Plot the geometry (Vp) ####
if plot_figure:
    fig = plt.figure(figsize=plt.figaspect(1))
    ax = fig.add_subplot(111, projection='3d')

    nTfv = np.logical_not(Tfv)
    ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], label='Traction-free region')
    ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2])
    ax.legend()

    ax.view_init(azim=0, elev=0)
    plt.show()
# Out:
# data, connectivity: (4558, 3) (9112, 3)
# id of nodes, edges, facets: (4558,) (13668, 2) (9112, 3)
# coord of nodes, edges, facets: (4558, 3) (13668, 2, 3) (9112, 3, 3)

# %% [markdown]
# Then we determine the original radius of the particle, assuming the particle is incompressible. The total volume can be estimated by adding the volume of the tetrahedrons. The volume of a tetrahedron is calculated as:
#
# $$
# V_{0123}=\frac{1}{6}
# \begin{vmatrix}
#  x_1 & y_1 & z_1 & 1\\
#  x_2 & y_2 & z_2 & 1\\
#  x_3 & y_3 & z_3 & 1\\
#  0 & 0 & 0 & 1\\
# \end{vmatrix}
# $$

# %%
tet = np.zeros((Fs.shape[0], 4, 4))
tet[:,:-1,:-1] = Fp
tet[:,:,-1] = 1
vol = np.sum(np.linalg.det(tet)/6, axis=0)
r0 = np.cbrt(vol/(4/3*np.pi))
print('V = %.4f, r0 = %.4f'%(vol, r0))
# Out:
# V = 307.2709, r0 = 4.1861

# %% [markdown]
# We need to solve the reverse problem of a deformed shape. We will try the following methods to tackle this problem:
#
# 1. Assume $r$-direction deformation only, using the solution as initial guess to the optimization
# 2. LSQ solving coeffs of the SH solutions for fitting both the traction-free boundary and the shape

# %% [markdown]
# Conversion between complex and real spherical harmonics, for $m>0$
#
# $$
# f_{lm} = \left[f_l^m+(-1)^mf_l^{-m}\right]/\sqrt{2}\\
# f_{l-m}=i\left[f_l^m-(-1)^mf_l^{-m}\right]/\sqrt{2}\\
# f_l^m = (f_{lm}-if_{l-m})/\sqrt{2}\\
# f_l^{-m} = (-1)^m(f_{lm}+if_{l-m})/\sqrt{2}
# $$
#
# for $m=0$:
#
# $$
# f_{l0} = f_l^0
# $$

# %% [markdown]
# ## 2. LSQ solving SH coeffs for displacement field
#
# Obviously, the decomposition is not satisfactory. It is not reasonable to assume the deformation is only on $r$-direction. In this section, we will try to optimize SH coeffs, so that the deformed shape is closest to the data. Notice that the integral of a spherical harmonic function on the sphere surface is:
#
# $$
# \int_0^{2\pi}\!\int_0^{\pi}Y_l^m(\theta,\varphi)\sin\theta d\theta d\varphi = 4\pi\delta_{l0}\delta_{m0}
# $$
#
# Therefore, only the $Y_0^0$ term controls the rigid body translation (constant). If we only impose higher mode spherical harmonics, there will be no rigid body motion.

# %% [markdown]
# ### Develop the interpolation function for $u_r(\theta,\varphi)$ from data

# %%
f_interp = Ur_interp(Vp/r0, lmax=lJmax+20, plot_figure=plot_figure)
# Define shape reference
latsdeg, lonsdeg = pyshtools.expand.GLQGridCoord(lJmax, extend=True)
lon0, lat0 = np.meshgrid(lonsdeg, latsdeg)
X0surf = np.stack([lat0, lon0], axis=-1)
X0 = GLQCartCoord(lJmax)
# Out:
# shape fitting accuracy: 0.00038950425952055873

# %% [markdown]
# ### Define the initial guess

# %%
import glob
filelist = glob.glob('AK_'+savename+'_??.npz')
print(savename)
print(filelist)
nfile = len(filelist)
if nfile > 0:
    u0_surf = np.load('AK_'+savename+'_%02d.npz'%(nfile-1))['u_surf_list'][-1, ...]
    if u0_surf.size < np.prod(X0surf.shape):
        if len(u0_surf.shape) != 3:
            u0_surf = u0_surf.reshape(lJmax+1, 2*lJmax+1, 2)
        new_u0_surf = np.zeros_like(X0surf)
        new_u0_surf[:, :-1, :] = u0_surf
        new_u0_surf[:, -1,  :] = u0_surf[:, 0, :]
        u0_surf = new_u0_surf
elif init_guess_type == 'ur-only':
    u0_surf = np.zeros_like(X0surf)

U0vec, aK, T0vec = usurf2vec(u0_surf, f_interp, lJmax)
if plot_figure:
    fig, ax = plt.subplots()
    ax.plot(np.abs(T0vec))
    plt.show()
    print('Displacement in Spherical Coordinates...')
    fig, ax = visSHVec(U0vec*r0, lmax_plot=lmax_plot, SphCoord=True, Complex=True,
                       n_vrange=(-1, 1), s_vrange=(0, 1),
                       config_quiver=(2, 3, 'k', 10), lonshift=180, figsize=(6,3))
    print('Traction in Spherical Coordinates...')
    fig, ax = visSHVec((T0vec)*mu0, lmax_plot=lmax_plot, SphCoord=True, Complex=True, 
                       n_vrange=(-100, 100), s_vrange=(0, 50),
                       config_quiver=(2, 3, 'k', 500), lonshift=180, figsize=(6,3))
# Out:
# Particle01_b1e+00_lmax20smoothed_1um_dilated_g1e+00
# []
# Integrating modes to a matrix
# 1323 1323
# Integrating modes to a matrix
# 1323 1323
# Displacement in Spherical Coordinates...
# Traction in Spherical Coordinates...

# %% [markdown]
# ### Define the traction free region based on the initial guess

# %%
# Define weights and traction free region
if dilated == '_softedge':
    isTfv = calculateTfv(U0vec, lJmax, Vp/r0, mask, lat_weight=True)
else:
    isTfv = calculateTfv(U0vec, lJmax, Vp/r0, Tfv, lat_weight=True)
print(isTfv.shape)
# Out:
# (21, 42)

# %% [markdown]
# ## Coordinate transformation
#
# The degree of freedom is defined as surface-shift $(\theta,\varphi)_i$, where $i=1\dots N, N = (l_{\max}+1)(2l_{\max}+1)$. Transformation from the surface-shift representation to displacement in Cartesian coordinates is written as:
#
# $$
# r_i = r_i(\theta_i, \varphi_i) \\
# \vec{x}_i = \mathbf{Q}\cdot[r,\theta,\varphi]\\
# \vec{u}_i = \vec{x}_i - \vec{X}_i
# $$
#
# We use the 3-point formulation to obtain the numerical difference:
#
# $$
# f'(x_i)\approx\frac{f(x_{i-1})+f(x_{i+1})-2f(x_{i})}{h}
# $$
#
# where $x_{i+1}-x_i=x_i-x_{i-1}=h$
#
# ### Linear transformation
#
# The linear relation between `umesh`, `Uvec`, `Tvec`, and `Tmesh` can be written as:
#
# $$
# U_{mesh} = \sum \hat{U}_{lmk}Y_l^m\hat{\mathbf{e}}_k \\
# \hat{U}_{lmk} = \mathbf{D}\cdot A_K = \mathbf{S}U_{mesh}\\
# \hat{T}_{lmk} = \mathbf{C}\cdot A_K = \mathbf{C}\mathbf{D}^{-1}\mathbf{S}U_{mesh} \\
# T_{mesh} = \sum \hat{T}_{lmk}Y_l^m\hat{\mathbf{e}}_k
# $$
#
# Thus it can be simplified as:
#
# $$
# T_{mesh} = \mathbf{L}U_{mesh}
# $$
#
# where $\mathbf{S}\in\mathbb{C}^{3M}\times\mathbb{C}^{3N}, \mathbf{L}\in\mathbb{R}^{3N}\times\mathbb{R}^{3N}, M=(l_{\max}+1)^2,N=(l_{\max}+1)(2l_{\max}+1)$ is the number of grid nodes on the sphere surface by GLQ meshing.
#
# Note that $\mathbf{L}$ is positive semidefinite, which does *NOT* satisfy $L=L^T$
#
# $\mathbf{S}$ and $\mathbf{L}$ can be obtained by operating the algorithm on each column of an *identity matrix* $I$, since they are linear operations.
#
# ## Jacobian of the target function
#
# The target function is written as:
# $$
# f(\vec{u}_s)=T_{res}+\beta E_{el}+\gamma E_{pen}=
# {1\over N}\vec{T}_{mesh}^T\mathbf{P}\vec{T}_{mesh}+2\pi\beta\vec{U}^{(K)}\cdot\vec{T}^{(K)} + |\mathbf{Q}\vec{T}^{(K)}|^2
# $$
#
# where the surface shift $[\vec{u}_s]_i=(\theta,\varphi)_i$. Thus the Jacobian for residual traction and elastic energy can be written separately as:
#
# $$
# {\partial E_{el}\over\partial U_{mesh}}=
# 2\pi\left(\mathbf{S}^T\mathbf{CD^{-1}S}+\mathbf{S^TD^{-T}C}^T\mathbf{S}\right)\vec{U}_{mesh}
# $$
#
# $$
# {\partial T_{res}\over\partial U_{mesh}}={2\over N}\mathbf{L}^T\mathbf{P}\mathbf{L}\vec{U}_{mesh}
# $$
#
# $$
# {\partial E_{pen}\over\partial U_{mesh}}=
# (\mathbf{QCD^{-1}S})^H\mathbf{QCD^{-1}S}U_{mesh}
# $$
#
# $$
# \frac{\partial f}{\partial\vec{u}_s}=
# \left[{2\over N}\mathbf{L}^T\mathbf{P}\mathbf{L}+2\pi\beta\left(\mathbf{S}^T\mathbf{CD^{-1}S}+\mathbf{S^TD^{-T}C}^T\mathbf{S}\right)\right]\vec{U}_{mesh}\frac{\partial\vec{U}_{mesh}}{\partial\vec{u}_s}
# $$
#
# where diagonal matrix $\mathbf{P}$ is the matrix that selects the traction vector on the traction-free surface, and diagonal matrix $\mathbf{Q}$ is the anti-aliasing damping coefficients for high-order traction modes.

# %%
lmax = lJmax
ldamp_hi = lmax; ldamp_lo = lmax - 5;
lv, _ = LM_list(lmax); lv_ones = np.ones_like(lv);
lv_lim = np.minimum(np.maximum(lv, ldamp_lo), ldamp_hi)
ldamp = (np.maximum(lv_lim-ldamp_lo, 0) / (ldamp_hi - ldamp_lo))**1
Q = spm.csr_matrix(np.diag(np.tile(ldamp, 3)).astype(np.complex))
# print(Q.shape, CDmat.shape)
plt.plot(ldamp)
plt.show()

# %%
# Calculating L, S, P matrices for Jacobian evaluation
if not os.path.exists('JacMats.npz'):
    tic = time.time()
    Lmat = genLmat(lJmax, Cmat=Cmat, Dmat=Dmat)
    print('Time for generating L matrix: %.2fs'%(time.time() - tic))
    tic = time.time()
    Smat = genSmat(lJmax, Cmat=Cmat, Dmat=Dmat)
    print('Time for generating S matrix: %.2fs'%(time.time() - tic))
    Dinv = spm.linalg.inv(Dmat)
    CDmat = Cmat.dot(Dinv)
    tic = time.time()
    CDSmat = np.asmatrix(CDmat.dot(Smat))
    SHCDS = np.asmatrix(Smat).H.dot(CDSmat)
    print('Time for generating S^HCD^{-1}S matrix: %.2fs'%(time.time() - tic))
    np.savez_compressed('JacMats.npz', Lmat=Lmat, Smat=Smat, CDSmat=CDSmat, SHCDS=SHCDS)
else:
    loadnpz = np.load('JacMats.npz')
    Lmat = np.asmatrix(loadnpz['Lmat'])
    Smat = np.asmatrix(loadnpz['Smat'])
    CDSmat= np.asmatrix(loadnpz['CDSmat'])
    SHCDS = np.asmatrix(loadnpz['SHCDS'])
tic = time.time()
QCDSmat = Q.dot(CDSmat)
QCDSHQCDS = QCDSmat.H.dot(QCDSmat).real
print('Time for generating QCDSHQCDS matrix: %.2fs'%(time.time() - tic))
tic = time.time()
P = np.diag(np.stack([isTfv]*3, axis=-1).flatten())
TresJac = 2*np.asmatrix(np.dot(np.dot(Lmat.T, P), Lmat))/(lJmax+1)/(lJmax*2+1) 
EelJac  = 2*np.pi*(SHCDS+SHCDS.H)
penJac  = QCDSHQCDS+QCDSHQCDS.H
print('time of matrix build:', time.time() - tic)
# Out:
# Time for generating L matrix: 9.10s
# Time for generating S matrix: 0.98s
# Time for generating S^HCD^{-1}S matrix: 1.19s
# Time for generating QCDSHQCDS matrix: 0.23s
# time of matrix build: 0.5696761608123779

# %% [markdown]
# The cost function value of the initial guess is:

# %%
T0dist = Tvec2Tres(T0vec, lJmax, isTfv=isTfv, norm_order=myord)
E0el = np.vdot(U0vec, T0vec).real*2*np.pi
pen0 = np.vdot(Q.dot(T0vec), Q.dot(T0vec)).real
print('Traction residual: %.4e Pa'%(np.sqrt(T0dist)*mu0))
print('Elastic energy: %.4e pJ'%(E0el*(r0/1e6)**3*mu0*1e12))
print('funval: %.4e %.4e %.4e'%(T0dist, E0el, pen0))
# Out:
# Traction residual: 6.9647e+02 Pa
# Elastic energy: 5.3244e-03 pJ
# funval: 2.5832e+00 1.6750e-01 3.6778e-04

# %%
target_args = (f_interp, lJmax, mybeta, myord, X0surf, X0, isTfv, Cmat, Dmat, 
               mu0, nu0, np.array([1]), np.array([1]), eps, '2-point', (TresJac, EelJac, penJac), mygamma)

def print_iter(xk):
    Uvec, aK, Tvec = usurf2vec(xk, f_interp, lJmax, X0surf=X0surf, X0=X0, Cmat=Cmat, Dmat=Dmat)
    Tdist = Tvec2Tres(Tvec, lJmax, isTfv=isTfv, norm_order=myord)
    Eel = np.vdot(Uvec, Tvec).real*2*np.pi
    pen = np.vdot(Q.dot(Tvec), Q.dot(Tvec)).real
    dr  = usurf2dr2(xk, *target_args)
    print('%13.4ePa%13.4epJ%13.4e%13.4e%13.4e%13.4e'%(np.sqrt(Tdist)*mu0, Eel*(r0/1e6)**3*mu0*1e12, Tdist, Eel, pen, dr))

u_surf = u0_surf.flatten().copy()
u_surf_list = [u_surf, ]
tic_start = time.time()
for i in range(N_period):
    print('Period %4d  Tr'%i, ' '*10, 'Eel', ' '*9, 'f0',' '*9, 'f1', ' '*9, 'f2', ' '*9, 'f')
    tic = time.time()
    u_res = minimize(usurf2dr2, u_surf.flatten(), args=target_args, jac=grad_usurf2dr2,
                     method = minimizer, options=minimizer_config, callback=print_iter)
    print('Iteration Time: %.2fs'%(time.time() - tic))
    u_surf = u_res.x.copy()
    u_surf_list.append(u_surf)
    if u_res.success:
        break
    if i%10 == 9:
        print('update isTfv at step %d'%i)
        Uvec, aK, Tvec = usurf2vec(u_surf, f_interp, lJmax, X0surf=X0surf, X0=X0, Cmat=Cmat, Dmat=Dmat)
        if dilated == '_softedge':
            isTfv = calculateTfv(Uvec, lJmax, Vp/r0, mask, lat_weight=True)
        else:
            isTfv = calculateTfv(Uvec, lJmax, Vp/r0, Tfv, lat_weight=True)
        P = np.diag(np.stack([isTfv]*3, axis=-1).flatten())
        TresJac = 2*np.asmatrix(np.dot(np.dot(Lmat.T, P), Lmat))/(lJmax+1)/(lJmax*2+1)
        target_args = (f_interp, lJmax, mybeta, myord, X0surf, X0, isTfv, Cmat, Dmat, 
               mu0, nu0, np.array([1]), np.array([1]), eps, '2-point', (TresJac, EelJac, penJac), mygamma)
print('Total Wall Time: %.2fs'%(time.time() - tic_start))
# Out:
# Period    0  Tr            Eel           f0           f1           f2           f
#    1.0195e+02Pa   3.2514e-03pJ   5.5346e-02   1.0228e-01   9.7825e-04   1.5861e-01
#    4.8639e+01Pa   3.1517e-03pJ   1.2598e-02   9.9149e-02   9.3912e-04   1.1269e-01
#    4.6328e+01Pa   3.0832e-03pJ   1.1430e-02   9.6994e-02   9.7495e-04   1.0940e-01
#    4.5245e+01Pa   3.0805e-03pJ   1.0902e-02   9.6908e-02   8.6933e-04   1.0868e-01
#    4.3190e+01Pa   3.0228e-03pJ   9.9339e-03   9.5093e-02   8.8828e-04   1.0592e-01
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.105915
#          Iterations: 5
#          Function evaluations: 34
#          Gradient evaluations: 34
# Iteration Time: 5.91s
# Period    1  Tr            Eel           f0           f1           f2           f
#    4.2533e+01Pa   3.0211e-03pJ   9.6339e-03   9.5042e-02   3.8947e-04   1.0506e-01
#    4.2222e+01Pa   3.0021e-03pJ   9.4936e-03   9.4443e-02   4.5125e-04   1.0439e-01
#    4.1446e+01Pa   2.9811e-03pJ   9.1479e-03   9.3783e-02   9.0342e-04   1.0383e-01
#    3.9173e+01Pa   2.9414e-03pJ   8.1720e-03   9.2534e-02   5.0209e-04   1.0121e-01
#    3.8108e+01Pa   2.9422e-03pJ   7.7335e-03   9.2558e-02   5.6124e-04   1.0085e-01
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.100853
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.72s
# Period    2  Tr            Eel           f0           f1           f2           f
#    3.7697e+01Pa   2.9382e-03pJ   7.5679e-03   9.2433e-02   2.6283e-04   1.0026e-01
#    3.7683e+01Pa   2.9336e-03pJ   7.5620e-03   9.2288e-02   2.7389e-04   1.0012e-01
#    3.7683e+01Pa   2.9286e-03pJ   7.5621e-03   9.2130e-02   2.4811e-04   9.9940e-02
#    3.7039e+01Pa   2.9301e-03pJ   7.3061e-03   9.2179e-02   2.8775e-04   9.9773e-02
#    3.6846e+01Pa   2.9276e-03pJ   7.2298e-03   9.2100e-02   3.6769e-04   9.9698e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.099698
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.50s
# Period    3  Tr            Eel           f0           f1           f2           f
#    3.6815e+01Pa   2.9219e-03pJ   7.2179e-03   9.1919e-02   3.3427e-04   9.9471e-02
#    3.6543e+01Pa   2.9181e-03pJ   7.1117e-03   9.1801e-02   2.6511e-04   9.9178e-02
#    3.6738e+01Pa   2.9111e-03pJ   7.1876e-03   9.1580e-02   2.7399e-04   9.9042e-02
#    3.3550e+01Pa   2.8925e-03pJ   5.9944e-03   9.0996e-02   2.6055e-04   9.7250e-02
#    3.1661e+01Pa   2.8752e-03pJ   5.3383e-03   9.0452e-02   3.9046e-04   9.6181e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.096181
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.63s
# Period    4  Tr            Eel           f0           f1           f2           f
#    3.0494e+01Pa   2.8810e-03pJ   4.9521e-03   9.0634e-02   3.5658e-04   9.5943e-02
#    3.0583e+01Pa   2.8779e-03pJ   4.9810e-03   9.0537e-02   2.5622e-04   9.5774e-02
#    3.0403e+01Pa   2.8793e-03pJ   4.9227e-03   9.0579e-02   2.5236e-04   9.5754e-02
#    3.0493e+01Pa   2.8742e-03pJ   4.9518e-03   9.0421e-02   2.6527e-04   9.5638e-02
#    3.0261e+01Pa   2.8752e-03pJ   4.8767e-03   9.0452e-02   2.7936e-04   9.5608e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095608
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.63s
# Period    5  Tr            Eel           f0           f1           f2           f
#    3.0369e+01Pa   2.8735e-03pJ   4.9115e-03   9.0397e-02   2.7150e-04   9.5580e-02
#    3.0253e+01Pa   2.8731e-03pJ   4.8740e-03   9.0385e-02   2.4198e-04   9.5501e-02
#    3.0370e+01Pa   2.8714e-03pJ   4.9118e-03   9.0330e-02   2.4480e-04   9.5487e-02
#    3.0140e+01Pa   2.8721e-03pJ   4.8378e-03   9.0352e-02   2.5078e-04   9.5441e-02
#    3.0253e+01Pa   2.8699e-03pJ   4.8740e-03   9.0285e-02   2.5092e-04   9.5410e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095410
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.27s
# Period    6  Tr            Eel           f0           f1           f2           f
#    3.0138e+01Pa   2.8709e-03pJ   4.8370e-03   9.0314e-02   2.4914e-04   9.5400e-02
#    3.0187e+01Pa   2.8693e-03pJ   4.8527e-03   9.0266e-02   2.3780e-04   9.5356e-02
#    3.0021e+01Pa   2.8705e-03pJ   4.7995e-03   9.0303e-02   2.3902e-04   9.5342e-02
#    2.9836e+01Pa   2.8679e-03pJ   4.7407e-03   9.0221e-02   2.8711e-04   9.5249e-02
#    3.0083e+01Pa   2.8643e-03pJ   4.8195e-03   9.0107e-02   2.7595e-04   9.5202e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095202
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.52s
# Period    7  Tr            Eel           f0           f1           f2           f
#    2.9809e+01Pa   2.8662e-03pJ   4.7322e-03   9.0168e-02   2.6797e-04   9.5169e-02
#    2.9833e+01Pa   2.8653e-03pJ   4.7396e-03   9.0139e-02   2.3337e-04   9.5112e-02
#    2.9706e+01Pa   2.8663e-03pJ   4.6995e-03   9.0172e-02   2.3244e-04   9.5104e-02
#    2.9710e+01Pa   2.8650e-03pJ   4.7007e-03   9.0130e-02   2.4325e-04   9.5074e-02
#    2.9536e+01Pa   2.8661e-03pJ   4.6459e-03   9.0164e-02   2.5610e-04   9.5066e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095066
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.56s
# Period    8  Tr            Eel           f0           f1           f2           f
#    2.9681e+01Pa   2.8644e-03pJ   4.6914e-03   9.0113e-02   2.4803e-04   9.5052e-02
#    2.9634e+01Pa   2.8645e-03pJ   4.6766e-03   9.0115e-02   2.3327e-04   9.5025e-02
#    2.9544e+01Pa   2.8652e-03pJ   4.6484e-03   9.0138e-02   2.3362e-04   9.5020e-02
#    2.9597e+01Pa   2.8641e-03pJ   4.6651e-03   9.0101e-02   2.3595e-04   9.5002e-02
#    2.9362e+01Pa   2.8653e-03pJ   4.5913e-03   9.0140e-02   2.4314e-04   9.4975e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094975
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.61s
# Period    9  Tr            Eel           f0           f1           f2           f
#    2.9474e+01Pa   2.8638e-03pJ   4.6264e-03   9.0092e-02   2.4018e-04   9.4958e-02
#    2.9442e+01Pa   2.8638e-03pJ   4.6164e-03   9.0092e-02   2.2926e-04   9.4938e-02
#    2.9506e+01Pa   2.8629e-03pJ   4.6364e-03   9.0063e-02   2.2874e-04   9.4928e-02
#    2.9328e+01Pa   2.8639e-03pJ   4.5805e-03   9.0094e-02   2.3131e-04   9.4906e-02
#    2.9365e+01Pa   2.8626e-03pJ   4.5923e-03   9.0055e-02   2.3675e-04   9.4884e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094884
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.41s
# update isTfv at step 9
# Period   10  Tr            Eel           f0           f1           f2           f
#    2.9996e+01Pa   2.8644e-03pJ   4.7916e-03   9.0110e-02   2.3167e-04   9.5133e-02
#    2.9937e+01Pa   2.8633e-03pJ   4.7729e-03   9.0078e-02   2.4606e-04   9.5097e-02
#    3.0057e+01Pa   2.8618e-03pJ   4.8111e-03   9.0031e-02   2.3929e-04   9.5081e-02
#    2.9847e+01Pa   2.8632e-03pJ   4.7440e-03   9.0074e-02   2.3725e-04   9.5055e-02
#    2.9893e+01Pa   2.8622e-03pJ   4.7589e-03   9.0042e-02   2.3927e-04   9.5041e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.095041
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.44s
# Period   11  Tr            Eel           f0           f1           f2           f
#    2.9745e+01Pa   2.8635e-03pJ   4.7119e-03   9.0083e-02   2.3461e-04   9.5029e-02
#    2.9787e+01Pa   2.8627e-03pJ   4.7252e-03   9.0056e-02   2.2892e-04   9.5010e-02
#    2.9559e+01Pa   2.8640e-03pJ   4.6529e-03   9.0100e-02   2.3401e-04   9.4987e-02
#    2.9499e+01Pa   2.8616e-03pJ   4.6340e-03   9.0022e-02   2.7129e-04   9.4927e-02
#    2.8668e+01Pa   2.8630e-03pJ   4.3767e-03   9.0067e-02   2.9037e-04   9.4734e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094734
#          Iterations: 5
#          Function evaluations: 31
#          Gradient evaluations: 31
# Iteration Time: 4.97s
# Period   12  Tr            Eel           f0           f1           f2           f
#    2.8907e+01Pa   2.8598e-03pJ   4.4499e-03   8.9965e-02   2.6618e-04   9.4681e-02
#    2.8698e+01Pa   2.8598e-03pJ   4.3859e-03   8.9965e-02   2.2289e-04   9.4574e-02
#    2.8542e+01Pa   2.8610e-03pJ   4.3385e-03   9.0004e-02   2.2107e-04   9.4563e-02
#    2.8506e+01Pa   2.8598e-03pJ   4.3273e-03   8.9966e-02   2.2433e-04   9.4517e-02
#    2.8585e+01Pa   2.8588e-03pJ   4.3514e-03   8.9936e-02   2.2267e-04   9.4510e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094510
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.00s
# Period   13  Tr            Eel           f0           f1           f2           f
#    2.8575e+01Pa   2.8585e-03pJ   4.3484e-03   8.9925e-02   2.1694e-04   9.4490e-02
#    2.8710e+01Pa   2.8568e-03pJ   4.3894e-03   8.9873e-02   2.1809e-04   9.4480e-02
#    2.8566e+01Pa   2.8544e-03pJ   4.3458e-03   8.9798e-02   2.3504e-04   9.4379e-02
#    2.8747e+01Pa   2.8520e-03pJ   4.4008e-03   8.9722e-02   2.3563e-04   9.4358e-02
#    2.8764e+01Pa   2.8486e-03pJ   4.4060e-03   8.9614e-02   2.5927e-04   9.4279e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094279
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.81s
# Period   14  Tr            Eel           f0           f1           f2           f
#    2.8608e+01Pa   2.8497e-03pJ   4.3583e-03   8.9649e-02   2.5506e-04   9.4262e-02
#    2.8633e+01Pa   2.8481e-03pJ   4.3662e-03   8.9600e-02   2.3666e-04   9.4202e-02
#    2.8457e+01Pa   2.8494e-03pJ   4.3126e-03   8.9638e-02   2.3635e-04   9.4187e-02
#    2.8527e+01Pa   2.8464e-03pJ   4.3337e-03   8.9544e-02   2.2483e-04   9.4103e-02
#    2.8249e+01Pa   2.8480e-03pJ   4.2497e-03   8.9594e-02   2.3222e-04   9.4076e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094076
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.76s
# Period   15  Tr            Eel           f0           f1           f2           f
#    2.8355e+01Pa   2.8465e-03pJ   4.2818e-03   8.9549e-02   2.1670e-04   9.4048e-02
#    2.8270e+01Pa   2.8471e-03pJ   4.2561e-03   8.9568e-02   2.1689e-04   9.4041e-02
#    2.8183e+01Pa   2.8477e-03pJ   4.2300e-03   8.9587e-02   2.1684e-04   9.4034e-02
#    2.8275e+01Pa   2.8464e-03pJ   4.2577e-03   8.9545e-02   2.1941e-04   9.4022e-02
#    2.8214e+01Pa   2.8461e-03pJ   4.2393e-03   8.9536e-02   2.3082e-04   9.4007e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.094007
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.31s
# Period   16  Tr            Eel           f0           f1           f2           f
#    2.8091e+01Pa   2.8472e-03pJ   4.2025e-03   8.9571e-02   2.1999e-04   9.3993e-02
#    2.8168e+01Pa   2.8462e-03pJ   4.2254e-03   8.9539e-02   2.1746e-04   9.3981e-02
#    2.8248e+01Pa   2.8453e-03pJ   4.2494e-03   8.9509e-02   2.1710e-04   9.3975e-02
#    2.8147e+01Pa   2.8456e-03pJ   4.2192e-03   8.9520e-02   2.2375e-04   9.3963e-02
#    2.7887e+01Pa   2.8429e-03pJ   4.1414e-03   8.9435e-02   2.2033e-04   9.3797e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.093797
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.64s
# Period   17  Tr            Eel           f0           f1           f2           f
#    2.8030e+01Pa   2.8400e-03pJ   4.1841e-03   8.9344e-02   2.1863e-04   9.3746e-02
#    2.7963e+01Pa   2.8397e-03pJ   4.1640e-03   8.9335e-02   2.2560e-04   9.3724e-02
#    2.8330e+01Pa   2.8329e-03pJ   4.2742e-03   8.9120e-02   2.4629e-04   9.3640e-02
#    2.7895e+01Pa   2.8309e-03pJ   4.1439e-03   8.9057e-02   3.3672e-04   9.3538e-02
#    2.7587e+01Pa   2.8271e-03pJ   4.0528e-03   8.8937e-02   2.8306e-04   9.3273e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.093273
#          Iterations: 5
#          Function evaluations: 31
#          Gradient evaluations: 31
# Iteration Time: 5.00s
# Period   18  Tr            Eel           f0           f1           f2           f
#    2.7683e+01Pa   2.8226e-03pJ   4.0812e-03   8.8796e-02   2.7565e-04   9.3153e-02
#    2.7670e+01Pa   2.8209e-03pJ   4.0773e-03   8.8743e-02   2.3822e-04   9.3059e-02
#    2.7880e+01Pa   2.8171e-03pJ   4.1394e-03   8.8623e-02   2.3332e-04   9.2996e-02
#    2.7590e+01Pa   2.8180e-03pJ   4.0536e-03   8.8653e-02   2.4856e-04   9.2955e-02
#    2.7649e+01Pa   2.8139e-03pJ   4.0711e-03   8.8522e-02   2.5828e-04   9.2851e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.092851
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.63s
# Period   19  Tr            Eel           f0           f1           f2           f
#    2.7430e+01Pa   2.8158e-03pJ   4.0070e-03   8.8582e-02   2.4414e-04   9.2833e-02
#    2.7394e+01Pa   2.8154e-03pJ   3.9965e-03   8.8568e-02   2.3940e-04   9.2804e-02
#    2.7522e+01Pa   2.8128e-03pJ   4.0339e-03   8.8488e-02   2.3998e-04   9.2761e-02
#    2.7527e+01Pa   2.8113e-03pJ   4.0354e-03   8.8440e-02   2.4647e-04   9.2722e-02
#    2.7431e+01Pa   2.8114e-03pJ   4.0071e-03   8.8445e-02   2.5533e-04   9.2708e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.092708
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.24s
# update isTfv at step 19
# Period   20  Tr            Eel           f0           f1           f2           f
#    2.7659e+01Pa   2.8094e-03pJ   4.0740e-03   8.8382e-02   2.4174e-04   9.2698e-02
#    2.7472e+01Pa   2.8101e-03pJ   4.0193e-03   8.8402e-02   2.3820e-04   9.2659e-02
#    2.7641e+01Pa   2.8073e-03pJ   4.0687e-03   8.8314e-02   2.5282e-04   9.2635e-02
#    2.7388e+01Pa   2.8071e-03pJ   3.9948e-03   8.8308e-02   2.6642e-04   9.2570e-02
#    2.8490e+01Pa   2.7226e-03pJ   4.3226e-03   8.5650e-02   1.2357e-03   9.1209e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.091209
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.75s
# Period   21  Tr            Eel           f0           f1           f2           f
#    2.8028e+01Pa   2.7106e-03pJ   4.1835e-03   8.5272e-02   6.3748e-04   9.0093e-02
#    2.6727e+01Pa   2.7125e-03pJ   3.8041e-03   8.5332e-02   5.5615e-04   8.9692e-02
#    2.6353e+01Pa   2.7142e-03pJ   3.6985e-03   8.5386e-02   5.1822e-04   8.9603e-02
#    2.6214e+01Pa   2.7063e-03pJ   3.6595e-03   8.5136e-02   4.5031e-04   8.9246e-02
#    2.6119e+01Pa   2.7028e-03pJ   3.6330e-03   8.5029e-02   4.3286e-04   8.9094e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.089094
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.55s
# Period   22  Tr            Eel           f0           f1           f2           f
#    2.6198e+01Pa   2.7003e-03pJ   3.6551e-03   8.4950e-02   4.2536e-04   8.9030e-02
#    2.5986e+01Pa   2.6980e-03pJ   3.5961e-03   8.4878e-02   3.9906e-04   8.8873e-02
#    2.6157e+01Pa   2.6959e-03pJ   3.6435e-03   8.4809e-02   3.9616e-04   8.8849e-02
#    2.6119e+01Pa   2.6923e-03pJ   3.6329e-03   8.4698e-02   4.1705e-04   8.8748e-02
#    2.6093e+01Pa   2.6727e-03pJ   3.6259e-03   8.4080e-02   6.4015e-04   8.8346e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.088346
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.66s
# Period   23  Tr            Eel           f0           f1           f2           f
#    2.6449e+01Pa   2.6682e-03pJ   3.7254e-03   8.3940e-02   5.5654e-04   8.8222e-02
#    2.5865e+01Pa   2.6671e-03pJ   3.5628e-03   8.3905e-02   4.5978e-04   8.7928e-02
#    2.5691e+01Pa   2.6641e-03pJ   3.5148e-03   8.3811e-02   4.6752e-04   8.7793e-02
#    2.5743e+01Pa   2.6593e-03pJ   3.5291e-03   8.3659e-02   5.1128e-04   8.7699e-02
#    2.5637e+01Pa   2.6584e-03pJ   3.5002e-03   8.3631e-02   4.7847e-04   8.7609e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.087609
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.81s
# Period   24  Tr            Eel           f0           f1           f2           f
#    2.5678e+01Pa   2.6555e-03pJ   3.5114e-03   8.3541e-02   4.7381e-04   8.7526e-02
#    2.5539e+01Pa   2.6528e-03pJ   3.4734e-03   8.3453e-02   4.5305e-04   8.7379e-02
#    2.5661e+01Pa   2.6486e-03pJ   3.5067e-03   8.3323e-02   4.4723e-04   8.7277e-02
#    2.5520e+01Pa   2.6483e-03pJ   3.4683e-03   8.3314e-02   4.6426e-04   8.7247e-02
#    2.5665e+01Pa   2.6434e-03pJ   3.5079e-03   8.3158e-02   5.1866e-04   8.7184e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.087184
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.43s
# Period   25  Tr            Eel           f0           f1           f2           f
#    2.5601e+01Pa   2.6398e-03pJ   3.4903e-03   8.3046e-02   5.0610e-04   8.7042e-02
#    2.5410e+01Pa   2.6385e-03pJ   3.4384e-03   8.3005e-02   4.8401e-04   8.6927e-02
#    2.5600e+01Pa   2.6332e-03pJ   3.4900e-03   8.2837e-02   4.7005e-04   8.6797e-02
#    2.5288e+01Pa   2.6334e-03pJ   3.4055e-03   8.2845e-02   4.9137e-04   8.6742e-02
#    2.5303e+01Pa   2.6324e-03pJ   3.4095e-03   8.2812e-02   5.0816e-04   8.6730e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.086730
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.35s
# Period   26  Tr            Eel           f0           f1           f2           f
#    2.5373e+01Pa   2.6309e-03pJ   3.4285e-03   8.2764e-02   5.0374e-04   8.6696e-02
#    2.5212e+01Pa   2.6285e-03pJ   3.3850e-03   8.2689e-02   4.8798e-04   8.6562e-02
#    2.5389e+01Pa   2.6261e-03pJ   3.4328e-03   8.2615e-02   4.8340e-04   8.6532e-02
#    2.5444e+01Pa   2.6227e-03pJ   3.4478e-03   8.2507e-02   4.8502e-04   8.6440e-02
#    2.5243e+01Pa   2.6235e-03pJ   3.3935e-03   8.2532e-02   4.8629e-04   8.6412e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.086412
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 3.96s
# Period   27  Tr            Eel           f0           f1           f2           f
#    2.5430e+01Pa   2.6198e-03pJ   3.4440e-03   8.2415e-02   4.8797e-04   8.6347e-02
#    2.5136e+01Pa   2.6189e-03pJ   3.3646e-03   8.2388e-02   5.2741e-04   8.6280e-02
#    2.5104e+01Pa   2.6116e-03pJ   3.3562e-03   8.2159e-02   5.5360e-04   8.6069e-02
#    2.5380e+01Pa   2.6071e-03pJ   3.4303e-03   8.2016e-02   5.6000e-04   8.6007e-02
#    2.5175e+01Pa   2.5478e-03pJ   3.3753e-03   8.0153e-02   1.0759e-03   8.4604e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.084604
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 32
# Iteration Time: 5.22s
# Period   28  Tr            Eel           f0           f1           f2           f
#    2.4756e+01Pa   2.5482e-03pJ   3.2637e-03   8.0163e-02   7.5290e-04   8.4179e-02
#    2.4470e+01Pa   2.5433e-03pJ   3.1887e-03   8.0011e-02   6.2806e-04   8.3827e-02
#    2.4388e+01Pa   2.5433e-03pJ   3.1674e-03   8.0010e-02   6.3215e-04   8.3810e-02
#    2.4234e+01Pa   2.5432e-03pJ   3.1275e-03   8.0005e-02   6.1063e-04   8.3743e-02
#    2.4311e+01Pa   2.5420e-03pJ   3.1474e-03   7.9968e-02   6.0758e-04   8.3723e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.083723
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.41s
# Period   29  Tr            Eel           f0           f1           f2           f
#    2.4231e+01Pa   2.5423e-03pJ   3.1268e-03   7.9979e-02   6.0721e-04   8.3713e-02
#    2.4315e+01Pa   2.5366e-03pJ   3.1486e-03   7.9797e-02   6.3933e-04   8.3585e-02
#    2.4173e+01Pa   2.5360e-03pJ   3.1119e-03   7.9780e-02   6.5584e-04   8.3548e-02
#    2.4222e+01Pa   2.5228e-03pJ   3.1244e-03   7.9366e-02   6.9862e-04   8.3189e-02
#    2.4654e+01Pa   2.5142e-03pJ   3.2369e-03   7.9093e-02   6.6100e-04   8.2991e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.082991
#          Iterations: 5
#          Function evaluations: 30
#          Gradient evaluations: 30
# Iteration Time: 4.84s
# update isTfv at step 29
# Period   30  Tr            Eel           f0           f1           f2           f
#    2.3986e+01Pa   2.5160e-03pJ   3.0638e-03   7.9149e-02   6.5617e-04   8.2869e-02
#    2.3859e+01Pa   2.5132e-03pJ   3.0314e-03   7.9063e-02   6.1809e-04   8.2713e-02
#    2.3962e+01Pa   2.5117e-03pJ   3.0578e-03   7.9015e-02   6.1029e-04   8.2683e-02
#    2.3803e+01Pa   2.5103e-03pJ   3.0173e-03   7.8972e-02   6.3498e-04   8.2625e-02
#    2.3806e+01Pa   2.5090e-03pJ   3.0181e-03   7.8931e-02   6.2565e-04   8.2575e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.082575
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.39s
# Period   31  Tr            Eel           f0           f1           f2           f
#    2.3785e+01Pa   2.5076e-03pJ   3.0129e-03   7.8885e-02   6.2296e-04   8.2521e-02
#    2.3755e+01Pa   2.5058e-03pJ   3.0052e-03   7.8829e-02   6.1518e-04   8.2449e-02
#    2.3686e+01Pa   2.5057e-03pJ   2.9878e-03   7.8827e-02   6.1274e-04   8.2428e-02
#    2.3757e+01Pa   2.5015e-03pJ   3.0056e-03   7.8695e-02   6.3730e-04   8.2338e-02
#    2.3717e+01Pa   2.4987e-03pJ   2.9956e-03   7.8606e-02   6.8982e-04   8.2292e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.082292
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.45s
# Period   32  Tr            Eel           f0           f1           f2           f
#    2.3832e+01Pa   2.4971e-03pJ   3.0246e-03   7.8555e-02   6.4610e-04   8.2225e-02
#    2.3634e+01Pa   2.4970e-03pJ   2.9747e-03   7.8554e-02   6.1528e-04   8.2144e-02
#    2.3564e+01Pa   2.4939e-03pJ   2.9570e-03   7.8454e-02   6.4212e-04   8.2053e-02
#    2.3527e+01Pa   2.4902e-03pJ   2.9477e-03   7.8340e-02   6.4681e-04   8.1935e-02
#    2.3631e+01Pa   2.4883e-03pJ   2.9738e-03   7.8278e-02   6.4794e-04   8.1900e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.081900
#          Iterations: 5
#          Function evaluations: 30
#          Gradient evaluations: 30
# Iteration Time: 4.82s
# Period   33  Tr            Eel           f0           f1           f2           f
#    2.3539e+01Pa   2.4886e-03pJ   2.9509e-03   7.8288e-02   6.4513e-04   8.1884e-02
#    2.3552e+01Pa   2.4852e-03pJ   2.9540e-03   7.8181e-02   6.1234e-04   8.1748e-02
#    2.3454e+01Pa   2.4854e-03pJ   2.9294e-03   7.8188e-02   6.1517e-04   8.1732e-02
#    2.3395e+01Pa   2.4834e-03pJ   2.9148e-03   7.8125e-02   6.2424e-04   8.1664e-02
#    2.3477e+01Pa   2.4820e-03pJ   2.9351e-03   7.8081e-02   6.2789e-04   8.1644e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.081644
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.42s
# Period   34  Tr            Eel           f0           f1           f2           f
#    2.3380e+01Pa   2.4824e-03pJ   2.9109e-03   7.8095e-02   6.2057e-04   8.1626e-02
#    2.3368e+01Pa   2.4816e-03pJ   2.9079e-03   7.8068e-02   6.0878e-04   8.1585e-02
#    2.3416e+01Pa   2.4809e-03pJ   2.9201e-03   7.8047e-02   6.0824e-04   8.1575e-02
#    2.3372e+01Pa   2.4780e-03pJ   2.9091e-03   7.7955e-02   6.3837e-04   8.1502e-02
#    2.3406e+01Pa   2.4751e-03pJ   2.9175e-03   7.7863e-02   6.8525e-04   8.1466e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.081466
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.30s
# Period   35  Tr            Eel           f0           f1           f2           f
#    2.3360e+01Pa   2.4740e-03pJ   2.9060e-03   7.7829e-02   6.6270e-04   8.1398e-02
#    2.3260e+01Pa   2.4736e-03pJ   2.8811e-03   7.7818e-02   6.1666e-04   8.1316e-02
#    2.3313e+01Pa   2.4730e-03pJ   2.8944e-03   7.7798e-02   6.1197e-04   8.1304e-02
#    2.3272e+01Pa   2.4719e-03pJ   2.8843e-03   7.7765e-02   6.1193e-04   8.1261e-02
#    2.3211e+01Pa   2.4696e-03pJ   2.8690e-03   7.7692e-02   6.1623e-04   8.1177e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.081177
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.30s
# Period   36  Tr            Eel           f0           f1           f2           f
#    2.3222e+01Pa   2.4690e-03pJ   2.8718e-03   7.7671e-02   6.1451e-04   8.1158e-02
#    2.3156e+01Pa   2.4677e-03pJ   2.8556e-03   7.7633e-02   6.0618e-04   8.1095e-02
#    2.3253e+01Pa   2.4665e-03pJ   2.8794e-03   7.7592e-02   6.0275e-04   8.1075e-02
#    2.3259e+01Pa   2.4637e-03pJ   2.8811e-03   7.7505e-02   6.3112e-04   8.1017e-02
#    2.3161e+01Pa   2.4637e-03pJ   2.8566e-03   7.7507e-02   6.2917e-04   8.0993e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.080993
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.14s
# Period   37  Tr            Eel           f0           f1           f2           f
#    2.3178e+01Pa   2.4627e-03pJ   2.8608e-03   7.7474e-02   6.0186e-04   8.0937e-02
#    2.3110e+01Pa   2.4628e-03pJ   2.8442e-03   7.7479e-02   6.0272e-04   8.0926e-02
#    2.3065e+01Pa   2.4624e-03pJ   2.8331e-03   7.7466e-02   6.0159e-04   8.0900e-02
#    2.3097e+01Pa   2.4615e-03pJ   2.8410e-03   7.7436e-02   6.0756e-04   8.0884e-02
#    2.3093e+01Pa   2.4538e-03pJ   2.8399e-03   7.7193e-02   6.6068e-04   8.0693e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.080693
#          Iterations: 5
#          Function evaluations: 30
#          Gradient evaluations: 30
# Iteration Time: 4.79s
# Period   38  Tr            Eel           f0           f1           f2           f
#    2.3178e+01Pa   2.4525e-03pJ   2.8610e-03   7.7154e-02   6.3945e-04   8.0655e-02
#    2.2946e+01Pa   2.4514e-03pJ   2.8039e-03   7.7117e-02   6.0474e-04   8.0526e-02
#    2.2902e+01Pa   2.4515e-03pJ   2.7933e-03   7.7122e-02   6.0234e-04   8.0517e-02
#    2.2928e+01Pa   2.4507e-03pJ   2.7995e-03   7.7097e-02   5.9298e-04   8.0490e-02
#    2.2886e+01Pa   2.4507e-03pJ   2.7893e-03   7.7098e-02   5.9374e-04   8.0481e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.080481
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.44s
# Period   39  Tr            Eel           f0           f1           f2           f
#    2.2917e+01Pa   2.4503e-03pJ   2.7969e-03   7.7084e-02   5.9135e-04   8.0472e-02
#    2.2873e+01Pa   2.4500e-03pJ   2.7862e-03   7.7073e-02   5.9233e-04   8.0452e-02
#    2.2873e+01Pa   2.4495e-03pJ   2.7863e-03   7.7059e-02   5.8930e-04   8.0435e-02
#    2.2944e+01Pa   2.4471e-03pJ   2.8035e-03   7.6983e-02   6.0795e-04   8.0394e-02
#    2.2884e+01Pa   2.4456e-03pJ   2.7889e-03   7.6935e-02   6.1009e-04   8.0334e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.080334
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.14s
# update isTfv at step 39
# Period   40  Tr            Eel           f0           f1           f2           f
#    2.2789e+01Pa   2.4452e-03pJ   2.7657e-03   7.6923e-02   5.8635e-04   8.0275e-02
#    2.2823e+01Pa   2.4447e-03pJ   2.7740e-03   7.6909e-02   5.8460e-04   8.0267e-02
#    2.2771e+01Pa   2.4443e-03pJ   2.7613e-03   7.6895e-02   5.9174e-04   8.0248e-02
#    2.2906e+01Pa   2.4258e-03pJ   2.7942e-03   7.6313e-02   7.7108e-04   7.9878e-02
#    2.3068e+01Pa   2.4214e-03pJ   2.8337e-03   7.6176e-02   7.6436e-04   7.9774e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.079774
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.69s
# Period   41  Tr            Eel           f0           f1           f2           f
#    2.2719e+01Pa   2.4203e-03pJ   2.7488e-03   7.6141e-02   7.4175e-04   7.9631e-02
#    2.2368e+01Pa   2.4178e-03pJ   2.6646e-03   7.6060e-02   6.1620e-04   7.9341e-02
#    2.2373e+01Pa   2.4171e-03pJ   2.6657e-03   7.6040e-02   6.0214e-04   7.9308e-02
#    2.2228e+01Pa   2.4169e-03pJ   2.6312e-03   7.6033e-02   5.5964e-04   7.9224e-02
#    2.2214e+01Pa   2.4167e-03pJ   2.6279e-03   7.6026e-02   5.5729e-04   7.9211e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.079211
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.02s
# Period   42  Tr            Eel           f0           f1           f2           f
#    2.2223e+01Pa   2.4164e-03pJ   2.6301e-03   7.6018e-02   5.5530e-04   7.9204e-02
#    2.2186e+01Pa   2.4163e-03pJ   2.6212e-03   7.6015e-02   5.5504e-04   7.9192e-02
#    2.2177e+01Pa   2.4158e-03pJ   2.6191e-03   7.6000e-02   5.6237e-04   7.9181e-02
#    2.2177e+01Pa   2.4156e-03pJ   2.6191e-03   7.5993e-02   5.6093e-04   7.9173e-02
#    2.2157e+01Pa   2.4154e-03pJ   2.6145e-03   7.5986e-02   5.5305e-04   7.9153e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.079153
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.34s
# Period   43  Tr            Eel           f0           f1           f2           f
#    2.2161e+01Pa   2.4153e-03pJ   2.6154e-03   7.5982e-02   5.5232e-04   7.9150e-02
#    2.2147e+01Pa   2.4149e-03pJ   2.6121e-03   7.5971e-02   5.5395e-04   7.9137e-02
#    2.2161e+01Pa   2.4146e-03pJ   2.6154e-03   7.5960e-02   5.5694e-04   7.9132e-02
#    2.2138e+01Pa   2.4109e-03pJ   2.6099e-03   7.5846e-02   5.5891e-04   7.9015e-02
#    2.2153e+01Pa   2.4088e-03pJ   2.6135e-03   7.5777e-02   5.7971e-04   7.8970e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.078970
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.52s
# Period   44  Tr            Eel           f0           f1           f2           f
#    2.2056e+01Pa   2.4088e-03pJ   2.5906e-03   7.5777e-02   5.4149e-04   7.8909e-02
#    2.1959e+01Pa   2.4082e-03pJ   2.5680e-03   7.5760e-02   5.2682e-04   7.8855e-02
#    2.1905e+01Pa   2.4073e-03pJ   2.5554e-03   7.5732e-02   5.2953e-04   7.8817e-02
#    2.1959e+01Pa   2.4063e-03pJ   2.5678e-03   7.5701e-02   5.2656e-04   7.8795e-02
#    2.1906e+01Pa   2.4053e-03pJ   2.5556e-03   7.5669e-02   5.3584e-04   7.8761e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.078761
#          Iterations: 5
#          Function evaluations: 33
#          Gradient evaluations: 33
# Iteration Time: 5.32s
# Period   45  Tr            Eel           f0           f1           f2           f
#    2.1895e+01Pa   2.4050e-03pJ   2.5530e-03   7.5658e-02   5.2155e-04   7.8732e-02
#    2.1837e+01Pa   2.4050e-03pJ   2.5395e-03   7.5659e-02   5.1668e-04   7.8715e-02
#    2.1827e+01Pa   2.4047e-03pJ   2.5372e-03   7.5650e-02   5.1664e-04   7.8703e-02
#    2.1841e+01Pa   2.4044e-03pJ   2.5403e-03   7.5640e-02   5.1155e-04   7.8692e-02
#    2.1808e+01Pa   2.4043e-03pJ   2.5328e-03   7.5637e-02   5.0798e-04   7.8678e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.078678
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.68s
# Period   46  Tr            Eel           f0           f1           f2           f
#    2.1811e+01Pa   2.4042e-03pJ   2.5334e-03   7.5634e-02   5.0776e-04   7.8675e-02
#    2.1806e+01Pa   2.4009e-03pJ   2.5324e-03   7.5530e-02   5.3056e-04   7.8593e-02
#    2.1815e+01Pa   2.3983e-03pJ   2.5344e-03   7.5447e-02   5.5935e-04   7.8541e-02
#    2.1602e+01Pa   2.3899e-03pJ   2.4852e-03   7.5182e-02   5.1867e-04   7.8186e-02
#    2.1496e+01Pa   2.3837e-03pJ   2.4607e-03   7.4988e-02   5.4784e-04   7.7996e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077996
#          Iterations: 5
#          Function evaluations: 31
#          Gradient evaluations: 31
# Iteration Time: 5.09s
# Period   47  Tr            Eel           f0           f1           f2           f
#    2.1232e+01Pa   2.3835e-03pJ   2.4008e-03   7.4982e-02   5.3021e-04   7.7913e-02
#    2.1129e+01Pa   2.3821e-03pJ   2.3775e-03   7.4937e-02   4.6018e-04   7.7775e-02
#    2.1090e+01Pa   2.3820e-03pJ   2.3686e-03   7.4935e-02   4.6038e-04   7.7764e-02
#    2.1001e+01Pa   2.3816e-03pJ   2.3487e-03   7.4923e-02   4.2881e-04   7.7700e-02
#    2.1004e+01Pa   2.3814e-03pJ   2.3495e-03   7.4918e-02   4.2514e-04   7.7693e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077693
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.10s
# Period   48  Tr            Eel           f0           f1           f2           f
#    2.0984e+01Pa   2.3814e-03pJ   2.3450e-03   7.4918e-02   4.2485e-04   7.7688e-02
#    2.0971e+01Pa   2.3811e-03pJ   2.3421e-03   7.4906e-02   4.2349e-04   7.7672e-02
#    2.0978e+01Pa   2.3807e-03pJ   2.3436e-03   7.4895e-02   4.1836e-04   7.7657e-02
#    2.0969e+01Pa   2.3804e-03pJ   2.3415e-03   7.4884e-02   4.1986e-04   7.7646e-02
#    2.0951e+01Pa   2.3797e-03pJ   2.3376e-03   7.4862e-02   4.1829e-04   7.7618e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077618
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.72s
# Period   49  Tr            Eel           f0           f1           f2           f
#    2.0944e+01Pa   2.3796e-03pJ   2.3361e-03   7.4860e-02   4.1605e-04   7.7612e-02
#    2.0917e+01Pa   2.3791e-03pJ   2.3300e-03   7.4844e-02   4.1328e-04   7.7588e-02
#    2.0916e+01Pa   2.3787e-03pJ   2.3297e-03   7.4832e-02   4.0480e-04   7.7566e-02
#    2.0911e+01Pa   2.3787e-03pJ   2.3286e-03   7.4831e-02   4.0459e-04   7.7564e-02
#    2.0888e+01Pa   2.3784e-03pJ   2.3235e-03   7.4822e-02   4.0177e-04   7.7547e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077547
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.78s
# update isTfv at step 49
# Period   50  Tr            Eel           f0           f1           f2           f
#    2.0891e+01Pa   2.3784e-03pJ   2.3243e-03   7.4821e-02   3.9987e-04   7.7545e-02
#    2.0893e+01Pa   2.3783e-03pJ   2.3247e-03   7.4819e-02   3.9886e-04   7.7543e-02
#    2.0886e+01Pa   2.3783e-03pJ   2.3230e-03   7.4818e-02   3.9871e-04   7.7540e-02
#    2.0878e+01Pa   2.3781e-03pJ   2.3212e-03   7.4812e-02   4.0095e-04   7.7534e-02
#    2.0894e+01Pa   2.3776e-03pJ   2.3250e-03   7.4795e-02   4.0486e-04   7.7525e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077525
#          Iterations: 5
#          Function evaluations: 27
#          Gradient evaluations: 27
# Iteration Time: 4.32s
# Period   51  Tr            Eel           f0           f1           f2           f
#    2.0866e+01Pa   2.3775e-03pJ   2.3185e-03   7.4795e-02   4.0190e-04   7.7516e-02
#    2.0857e+01Pa   2.3775e-03pJ   2.3168e-03   7.4793e-02   3.9503e-04   7.7505e-02
#    2.0857e+01Pa   2.3775e-03pJ   2.3165e-03   7.4793e-02   3.9431e-04   7.7504e-02
#    2.0856e+01Pa   2.3773e-03pJ   2.3165e-03   7.4789e-02   3.9340e-04   7.7498e-02
#    2.0839e+01Pa   2.3758e-03pJ   2.3126e-03   7.4740e-02   3.9267e-04   7.7445e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077445
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.69s
# Period   52  Tr            Eel           f0           f1           f2           f
#    2.0814e+01Pa   2.3758e-03pJ   2.3070e-03   7.4739e-02   3.9060e-04   7.7437e-02
#    2.0798e+01Pa   2.3756e-03pJ   2.3036e-03   7.4734e-02   3.8149e-04   7.7419e-02
#    2.0793e+01Pa   2.3756e-03pJ   2.3025e-03   7.4733e-02   3.8130e-04   7.7417e-02
#    2.0788e+01Pa   2.3754e-03pJ   2.3012e-03   7.4727e-02   3.8075e-04   7.7409e-02
#    2.0795e+01Pa   2.3751e-03pJ   2.3029e-03   7.4718e-02   3.7828e-04   7.7399e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077399
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 28
# Iteration Time: 4.58s
# Period   53  Tr            Eel           f0           f1           f2           f
#    2.0780e+01Pa   2.3751e-03pJ   2.2996e-03   7.4718e-02   3.7802e-04   7.7395e-02
#    2.0768e+01Pa   2.3750e-03pJ   2.2969e-03   7.4714e-02   3.7778e-04   7.7389e-02
#    2.0793e+01Pa   2.3743e-03pJ   2.3024e-03   7.4694e-02   3.7424e-04   7.7370e-02
#    2.0779e+01Pa   2.3734e-03pJ   2.2993e-03   7.4664e-02   3.8489e-04   7.7349e-02
#    2.0766e+01Pa   2.3714e-03pJ   2.2964e-03   7.4601e-02   3.8631e-04   7.7283e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077283
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.62s
# Period   54  Tr            Eel           f0           f1           f2           f
#    2.0697e+01Pa   2.3713e-03pJ   2.2812e-03   7.4598e-02   3.8084e-04   7.7260e-02
#    2.0651e+01Pa   2.3708e-03pJ   2.2712e-03   7.4582e-02   3.5483e-04   7.7208e-02
#    2.0648e+01Pa   2.3706e-03pJ   2.2704e-03   7.4577e-02   3.5112e-04   7.7199e-02
#    2.0638e+01Pa   2.3703e-03pJ   2.2683e-03   7.4569e-02   3.4692e-04   7.7184e-02
#    2.0615e+01Pa   2.3703e-03pJ   2.2631e-03   7.4568e-02   3.4678e-04   7.7178e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077178
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.12s
# Period   55  Tr            Eel           f0           f1           f2           f
#    2.0610e+01Pa   2.3703e-03pJ   2.2621e-03   7.4566e-02   3.4602e-04   7.7175e-02
#    2.0608e+01Pa   2.3702e-03pJ   2.2617e-03   7.4564e-02   3.4597e-04   7.7171e-02
#    2.0609e+01Pa   2.3701e-03pJ   2.2619e-03   7.4562e-02   3.4673e-04   7.7170e-02
#    2.0595e+01Pa   2.3701e-03pJ   2.2587e-03   7.4561e-02   3.4667e-04   7.7167e-02
#    2.0596e+01Pa   2.3700e-03pJ   2.2590e-03   7.4558e-02   3.4441e-04   7.7162e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.077162
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.00s
# Period   56  Tr            Eel           f0           f1           f2           f
#    2.0587e+01Pa   2.3699e-03pJ   2.2571e-03   7.4555e-02   3.4531e-04   7.7158e-02
#    2.0588e+01Pa   2.3699e-03pJ   2.2574e-03   7.4554e-02   3.4586e-04   7.7157e-02
#    2.0598e+01Pa   2.3685e-03pJ   2.2595e-03   7.4511e-02   3.5081e-04   7.7122e-02
#    2.0589e+01Pa   2.3678e-03pJ   2.2574e-03   7.4489e-02   3.5362e-04   7.7100e-02
#    2.0538e+01Pa   2.3639e-03pJ   2.2464e-03   7.4365e-02   3.3174e-04   7.6943e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.076943
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 32
# Iteration Time: 5.09s
# Period   57  Tr            Eel           f0           f1           f2           f
#    2.0365e+01Pa   2.3638e-03pJ   2.2087e-03   7.4363e-02   3.2597e-04   7.6897e-02
#    2.0304e+01Pa   2.3633e-03pJ   2.1955e-03   7.4346e-02   3.1411e-04   7.6856e-02
#    2.0317e+01Pa   2.3630e-03pJ   2.1982e-03   7.4339e-02   3.1395e-04   7.6851e-02
#    2.0339e+01Pa   2.3622e-03pJ   2.2031e-03   7.4312e-02   3.1625e-04   7.6832e-02
#    2.0289e+01Pa   2.3620e-03pJ   2.1923e-03   7.4307e-02   3.1522e-04   7.6814e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.076814
#          Iterations: 5
#          Function evaluations: 25
#          Gradient evaluations: 25
# Iteration Time: 4.05s
# Period   58  Tr            Eel           f0           f1           f2           f
#    2.0282e+01Pa   2.3618e-03pJ   2.1908e-03   7.4299e-02   3.0566e-04   7.6796e-02
#    2.0278e+01Pa   2.3617e-03pJ   2.1897e-03   7.4298e-02   3.0570e-04   7.6793e-02
#    2.0274e+01Pa   2.3615e-03pJ   2.1890e-03   7.4290e-02   3.0814e-04   7.6787e-02
#    2.0271e+01Pa   2.3614e-03pJ   2.1883e-03   7.4288e-02   3.0911e-04   7.6786e-02
#    2.0265e+01Pa   2.3614e-03pJ   2.1871e-03   7.4286e-02   3.0465e-04   7.6778e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.076778
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.21s
# Period   59  Tr            Eel           f0           f1           f2           f
#    2.0267e+01Pa   2.3613e-03pJ   2.1874e-03   7.4285e-02   3.0421e-04   7.6776e-02
#    2.0271e+01Pa   2.3611e-03pJ   2.1884e-03   7.4277e-02   3.0419e-04   7.6770e-02
#    2.0270e+01Pa   2.3606e-03pJ   2.1880e-03   7.4262e-02   3.0305e-04   7.6753e-02
#    2.0253e+01Pa   2.3602e-03pJ   2.1844e-03   7.4251e-02   3.0318e-04   7.6738e-02
#    2.0249e+01Pa   2.3599e-03pJ   2.1835e-03   7.4240e-02   3.0577e-04   7.6729e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.076729
#          Iterations: 5
#          Function evaluations: 29
#          Gradient evaluations: 29
# Iteration Time: 4.72s
# update isTfv at step 59
# Period   60  Tr            Eel           f0           f1           f2           f
#    2.0228e+01Pa   2.3599e-03pJ   2.1789e-03   7.4240e-02   3.0456e-04   7.6724e-02
#    2.0225e+01Pa   2.3599e-03pJ   2.1784e-03   7.4239e-02   3.0145e-04   7.6719e-02
#    2.0225e+01Pa   2.3598e-03pJ   2.1783e-03   7.4238e-02   3.0100e-04   7.6717e-02
#    2.0225e+01Pa   2.3597e-03pJ   2.1784e-03   7.4235e-02   3.0035e-04   7.6714e-02
#    2.0228e+01Pa   2.3595e-03pJ   2.1791e-03   7.4226e-02   3.0127e-04   7.6707e-02
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.076707
#          Iterations: 5
#          Function evaluations: 26
#          Gradient evaluations: 26
# Iteration Time: 4.17s
# Period   61  Tr            Eel           f0           f1           f2           f
#    2.0219e+01Pa   2.3594e-03pJ   2.1771e-03   7.4225e-02   3.0061e-04   7.6703e-02
#    2.0212e+01Pa   2.3594e-03pJ   2.1755e-03   7.4224e-02   2.9962e-04   7.6699e-02
# Optimization terminated successfully.
#          Current function value: 0.076699
#          Iterations: 2
#          Function evaluations: 10
#          Gradient evaluations: 10
# Iteration Time: 1.65s
# Total Wall Time: 281.99s

# %%
print(u_res)
u_surf = u_res.x

Usurfvec, aK, Tsurfvec = usurf2vec(u_surf, f_interp, lJmax, X0surf=X0surf, X0=X0, Cmat=Cmat, Dmat=Dmat)
Tsurfdist = Tvec2Tres(Tsurfvec, lJmax, isTfv=isTfv, norm_order=myord)
Eelsurf = np.vdot(Usurfvec, Tsurfvec).real*2*np.pi
print('Traction residual: %.4e Pa'%(np.sqrt(Tsurfdist)*mu0))
print('Elastic energy: %.4e pJ'%(Eelsurf*(r0/1e6)**3*mu0*1e12))
print('funval: %.4e %.4e'%(Tsurfdist, Eelsurf))

if plot_figure:
    fig, ax = plt.subplots()
    # ax.plot(np.abs(T_usr_vec))
    ax.plot(np.abs(Tsurfvec))
    plt.show()

    print('Displacement in Spherical Coordinates...')
    fig, ax = visSHVec(Usurfvec*r0, lmax_plot=lmax_plot, SphCoord=True, Complex=True, #s_vrange=(0,0.01),
                       config_quiver=(2, 3, 'k', 10), lonshift=180, figsize=(6,3))
    print('Traction in Spherical Coordinates...')
    fig, ax = visSHVec((Tsurfvec)*mu0, lmax_plot=lmax_plot, SphCoord=True, Complex=True, 
                       n_vrange=(-100, 100), s_vrange=(0, 50),
                       config_quiver=(2, 3, 'k', 500), lonshift=180, figsize=(6,3))
# Out:
#      fun: 0.07669925631221991
#      jac: array([-8.65405256e-08,  4.15292824e-07, -2.55443725e-08, ...,
#         3.72892751e-07,  0.00000000e+00,  0.00000000e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 10
#      nit: 2
#     njev: 10
#   status: 0
#  success: True
#        x: array([ 0.87971711, -0.24688062,  1.0006099 , ..., -0.17858742,
#         0.        ,  0.        ])
# Traction residual: 2.0212e+01 Pa
# Elastic energy: 2.3594e-03 pJ
# funval: 2.1755e-03 7.4224e-02
# Displacement in Spherical Coordinates...
# Traction in Spherical Coordinates...

# %%
# %matplotlib notebook
if plot_figure:
    # umesh_fine_scaled = SHVec2mesh(U0vec, lmax=lmax_plot, SphCoord=False, Complex=True)
    # tmesh_fine = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=False, Complex=True)
    umesh_fine_scaled = SHVec2mesh(Usurfvec, lmax=lmax_plot, SphCoord=False, Complex=True)
    tmesh_fine = SHVec2mesh(Tsurfvec*mu0, lmax=lmax_plot, SphCoord=False, Complex=True)
    print('Visualize the shape in 3D...')
    fig, ax = visSH3d(umesh_fine_scaled, cmesh=tmesh_fine, 
                      r0=r0, show=False, vmin=-100, vmax=100,
                      elevation=0, azimuth=0, 
                      surface=True, figsize=plt.figaspect(1))

    # reference data
    nTfv = np.logical_not(Tfv)
    #ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
    #ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
    ax.set_title('Front view')
    plt.show()
# Out:
# Visualize the shape in 3D...

# %%
print('Evaluate Displacement and Traction in Cartesian Coordinates for plotting 3d shape...')
umesh1 = SHVec2mesh(U0vec, lmax=lJmax, SphCoord=False, Complex=True)
tmesh1 = SHVec2mesh(T0vec*mu0, lmax=lJmax, SphCoord=False, Complex=True)
umesh1_fine = SHVec2mesh(U0vec, lmax=lmax_plot, SphCoord=False, Complex=True)
tmesh1_fine = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=False, Complex=True)
tmesh1_sph_fine = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=True, Complex=True)

print('Visualize the nodes in 3D...')
fig, ax = visSH3d(umesh1, cmesh=tmesh1, r0=r0, show=False, elevation=0, azimuth=0, surface=False, figsize=plt.figaspect(1))
nTfv = np.logical_not(Tfv)
ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
plt.show()
# Out:
# Evaluate Displacement and Traction in Cartesian Coordinates for plotting 3d shape...
# Visualize the nodes in 3D...

# %%
import glob
filelist = glob.glob('AK_'+savename+'_??.npz')
nfile = len(filelist)
np.savez('AK_'+savename+'_%02d.npz'%(nfile), 
         AK_iter=aK, u_surf_list=np.stack(u_surf_list, axis=0), 
         beta=mybeta, N=N_period)

# %%
matlab_file_path = 'output_data.mat'  # Saves in the current directory
umesh_fine_scaled = SHVec2mesh(Usurfvec, lmax=lmax_plot, SphCoord=True, Complex=True)
tmesh_fine = SHVec2mesh(Tsurfvec*mu0, lmax=lmax_plot, SphCoord=True, Complex=True)
matlab_data = {
    'mesh_xyz': umesh_fine_scaled,
    'mesh_T_sph': tmesh_fine,
}

savemat(matlab_file_path, matlab_data)

print(f"Data successfully saved to {matlab_file_path}")
# Out:
# Data successfully saved to output_data.mat
