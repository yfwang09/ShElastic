# %% [markdown]
# # Hydrogel-Cell Interaction Test Case
#
# In this case, we only have the deformed shape of the spherical hydrogel as shown in the next few cells.

# %%
import numpy as np
import scipy as sp
import scipy.sparse as spm
from scipy.sparse.linalg import lsqr, spsolve
from scipy.interpolate import RectBivariateSpline
from scipy.optimize import minimize
from scipy.io import loadmat, savemat

import matplotlib.pyplot as plt
from matplotlib import cm, colors
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import sys, time, os.path
from itertools import permutations
import pyshtools

sys.path.append('..')
from shelastic.shutil import SphCoord_to_CartCoord, CartCoord_to_SphCoord, GLQCartCoord
from shelastic.shutil import SHCilmToVector, SHVectorToCilm, SHVec2mesh, SHmesh2Vec
from shelastic.shutil import TransMat, l_coeffs, m_coeffs, LM_list, lmk2K, K2lmk
from shelastic.shbv import generate_submat, Uvec2Tvec, Tvec2Uvec
from shelastic.shvis  import plotfv, vismesh, visSHVec, visSH3d
from sphere_utils import loadCoeffs, arbitrary_force, Ur_interp
from sphere_utils import usurf2umesh, dumesh_dus, usurf2vec
from sphere_utils import Tvec2Tres, usurf2dr, calculateTfv, genSmat, genLmat, grad_usurf2dr

# %% [markdown]
# ## Input information

# %%
############################# change inputs here #################################
# Data file name
datadir = '../testdata'
smoothed = 'smoothed_3'
dilated = '_1um_dilated'
shapename = 'Shape1'
datafile = os.path.join(datadir, shapename+'_Coordinates_Cart_'+smoothed+'.csv')
connfile = os.path.join(datadir, shapename+'_Connectivity.csv')
maskfile = os.path.join(datadir, shapename+'_Mask'+dilated+'.csv')

# Material properties
mu0 = 300/3; nu0 = 0.499;

# Spherical Harmonics Analysis Settings
lJmax = 20; lKmax = lJmax; lmax_plot = 60;

# initial guess settings
init_guess_type = 'ur-only' #'ur-only' or 'true'

# regularizations
myalpha = 1     # traction magnitude
mybeta  = 1  # coefficient magnitude
mygamma = 1  

# program switches
plot_figure = True
savefig = True
myord = 1; # myord: p-norm order (1-mean value)

# minimization settings
N_period = 1000
maxiter_per_period = 5
CG_gtol = 1e-5
eps = 1e-5               # for jacobian

minimizer = 'CG'
minimizer_config = {'maxiter': maxiter_per_period, 'disp': True, 'gtol': CG_gtol}

# dump files for minimization
savename = shapename+('_b%.0e'%(mybeta))+('_lmax%d'%lJmax)+smoothed+dilated + '_g%.0e'%mygamma

# settings for loading \hat{U}, \hat{T} coefficients
Cmat, Dmat = loadCoeffs(mu0, nu0, lJmax, 'reg')
# Out:
# Integrating modes to a matrix
# 1323 1323
# Integrating modes to a matrix
# 1323 1323

# %% [markdown]
# ## Load the geometry

# %%
#### load the geometry ####
# Vs, Vp: list of nodes (nV, trivial), coordinates of the nodes (nVx3)
# Es, Ep: list of edges (nEx2), list of points on the edges (nEx2x3)
# Fs, Fp: list of facets (nFx3), list of points on the facets (nFx3x3)
# Tfv: traction free boundary map of the node list
# Tfe: traction free boundary map of the edge list
# Tff: traction free boundary map of the face list
# Tf_diluted: diluted traction free boundary map

data = np.genfromtxt(datafile, delimiter=',')
conn = np.genfromtxt(connfile, delimiter=',', dtype=np.int)
if dilated == '_softedge':
    masktype = np.float
else:
    masktype = np.int
if shapename == 'Shape4':
    mask = np.zeros_like(data[:,0]).astype(masktype)
else:
    mask = np.genfromtxt(maskfile, dtype=masktype)
print('data, connectivity:', data.shape, conn.shape)

Fs = conn - 1
Np = data.shape[0]
Vs = np.arange(Np)
edge_conn = spm.lil_matrix((Np, Np), dtype=bool)
for i, j in permutations(range(3), 2):
    edge_conn[Fs[:, i], Fs[:, j]] = True
Es = spm.triu(edge_conn).tocoo()
Es = np.vstack([Es.row, Es.col]).T
print('id of nodes, edges, facets:', Vs.shape, Es.shape, Fs.shape)
Vp = data[..., :3]
Ep = Vp[Es, :]; Fp = Vp[Fs, :];
print('coord of nodes, edges, facets:', Vp.shape, Ep.shape, Fp.shape)

if dilated == '_softedge':
    Tfv = (mask > 0.5)
else:
    Tfv = mask.astype(np.bool)

#### Plot the geometry (Vp) ####
if plot_figure:
    fig = plt.figure(figsize=plt.figaspect(1))
    ax = fig.add_subplot(111, projection='3d')

    nTfv = np.logical_not(Tfv)
    ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2])
    ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2])

    ax.view_init(azim=0, elev=0)
    plt.show()
# Out:
# data, connectivity: (8745, 3) (17486, 3)
# id of nodes, edges, facets: (8745,) (26229, 2) (17486, 3)
# coord of nodes, edges, facets: (8745, 3) (26229, 2, 3) (17486, 3, 3)

# %% [markdown]
# Then we determine the original radius of the particle, assuming the particle is incompressible. The total volume can be estimated by adding the volume of the tetrahedrons. The volume of a tetrahedron is calculated as:
#
# $$
# V_{0123}=\frac{1}{6}
# \begin{vmatrix}
#  x_1 & y_1 & z_1 & 1\\
#  x_2 & y_2 & z_2 & 1\\
#  x_3 & y_3 & z_3 & 1\\
#  0 & 0 & 0 & 1\\
# \end{vmatrix}
# $$

# %%
tet = np.zeros((Fs.shape[0], 4, 4))
tet[:,:-1,:-1] = Fp
tet[:,:,-1] = 1
vol = np.sum(np.linalg.det(tet)/6, axis=0)
r0 = np.cbrt(vol/(4/3*np.pi))
print('V = %.4f, r0 = %.4f'%(vol, r0))
# Out:
# V = 781.3546, r0 = 5.7137

# %% [markdown]
# We need to solve the reverse problem of a deformed shape. We will try the following methods to tackle this problem:
#
# 1. Assume $r$-direction deformation only, using the solution as initial guess to the optimization
# 2. LSQ solving coeffs of the SH solutions for fitting both the traction-free boundary and the shape

# %% [markdown]
# Conversion between complex and real spherical harmonics, for $m>0$
#
# $$
# f_{lm} = \left[f_l^m+(-1)^mf_l^{-m}\right]/\sqrt{2}\\
# f_{l-m}=i\left[f_l^m-(-1)^mf_l^{-m}\right]/\sqrt{2}\\
# f_l^m = (f_{lm}-if_{l-m})/\sqrt{2}\\
# f_l^{-m} = (-1)^m(f_{lm}+if_{l-m})/\sqrt{2}
# $$
#
# for $m=0$:
#
# $$
# f_{l0} = f_l^0
# $$

# %% [markdown]
# ## 2. LSQ solving SH coeffs for displacement field
#
# Obviously, the decomposition is not satisfactory. It is not reasonable to assume the deformation is only on $r$-direction. In this section, we will try to optimize SH coeffs, so that the deformed shape is closest to the data. Notice that the integral of a spherical harmonic function on the sphere surface is:
#
# $$
# \int_0^{2\pi}\!\int_0^{\pi}Y_l^m(\theta,\varphi)\sin\theta d\theta d\varphi = 4\pi\delta_{l0}\delta_{m0}
# $$
#
# Therefore, only the $Y_0^0$ term controls the rigid body translation (constant). If we only impose higher mode spherical harmonics, there will be no rigid body motion.

# %% [markdown]
# ### Develop the interpolation function for $u_r(\theta,\varphi)$ from data

# %%
f_interp = Ur_interp(Vp/r0, lmax=lJmax+20, plot_figure=plot_figure)
# Define shape reference
latsdeg, lonsdeg = pyshtools.expand.GLQGridCoord(lJmax)
lon0, lat0 = np.meshgrid(lonsdeg, latsdeg)
X0surf = np.stack([lat0, lon0], axis=-1)
X0 = GLQCartCoord(lJmax)
# Out:
# shape fitting accuracy: 0.00010807486662167604

# %% [markdown]
# ### Define the initial guess

# %%
import glob
filelist = glob.glob('AK_'+savename+'_??.npz')
nfile = len(filelist)
if nfile > 0:
    u_surf_list = np.load('AK_'+savename+'_%02d.npz'%(nfile-1))['u_surf_list']
else:
    raise FileNotFoundError()
    #if init_guess_type == 'ur-only':
    #u0_surf = np.zeros_like(X0surf)

# %%
u0_surf = u_surf_list[-1, ...]
U0vec, aK, T0vec = usurf2vec(u0_surf, f_interp, lJmax)
if plot_figure:
    fig, ax = plt.subplots()
    ax.plot(np.abs(T0vec))
    plt.show()
    print('Displacement in Spherical Coordinates...')
    fig, ax = visSHVec(U0vec*r0, lmax_plot=lmax_plot, SphCoord=True, Complex=True,
                       n_vrange=(-1, 1), s_vrange=(0, 1),
                       config_quiver=(2, 3, 'k', 10), lonshift=180, figsize=(6,3))
    print('Traction in Spherical Coordinates...')
    fig, ax = visSHVec((T0vec)*mu0, lmax_plot=lmax_plot, SphCoord=True, Complex=True, 
                       n_vrange=(-50, 50), s_vrange=(0, 25), cmap='RdBu', show=False,
                       config_quiver=(2, 3, 'k', 500), lonshift=180, figsize=(6,3))
    if savefig:
        fig[0].tight_layout(); fig[0].savefig(savename+'_Tn.png', transparent=True)
        fig[1].tight_layout(); fig[1].savefig(savename+'_Ts.png', transparent=True)
# Out:
# Integrating modes to a matrix
# 1323 1323
# Integrating modes to a matrix
# 1323 1323
# Displacement in Spherical Coordinates...
# Traction in Spherical Coordinates...

# %% [markdown]
# ### Define the traction free region based on the initial guess

# %%
# Define weights and traction free region
if dilated == '_softedge':
    isTfv = calculateTfv(U0vec, lJmax, Vp/r0, mask)
else:
    isTfv = calculateTfv(U0vec, lJmax, Vp/r0, Tfv)
print(isTfv.shape)
# Out:
# (21, 41)

# %%
lmax = lJmax
ldamp_hi = lmax; ldamp_lo = lmax - 5;
lv, _ = LM_list(lmax); lv_ones = np.ones_like(lv);
lv_lim = np.minimum(np.maximum(lv, ldamp_lo), ldamp_hi)
ldamp = (np.maximum(lv_lim-ldamp_lo, 0) / (ldamp_hi - ldamp_lo))**1
Q = spm.csr_matrix(np.diag(np.tile(ldamp, 3)).astype(np.complex))    

Treslist = []
Eel_list = []
Epenlist = []
drlist   = []
for i in range(len(u_surf_list)):
    u_surf = u_surf_list[i]
    print('Period %d'%i)
    Usurfvec, aK, Tsurfvec = usurf2vec(u_surf, f_interp, lJmax, X0surf=X0surf, X0=X0, Cmat=Cmat, Dmat=Dmat)
    Tsurfdist = Tvec2Tres(Tsurfvec, lJmax, isTfv=isTfv, norm_order=myord)
    Eelsurf = np.vdot(Usurfvec, Tsurfvec).real*2*np.pi
    Epensurf = np.vdot(Q.dot(Tsurfvec), Q.dot(Tsurfvec)).real
    dr = Tsurfdist + mybeta * Eelsurf + mygamma * Epensurf
    Treslist.append(Tsurfdist)
    Eel_list.append(mybeta*Eelsurf)
    Epenlist.append(mygamma*Epensurf)
    drlist.append(dr)
    print('Traction residual: %.4e Pa'%(Tsurfdist*mu0))
    print('Elastic energy: %.4e pJ'%(Eelsurf*(r0/1e6)**3*mu0*1e12))
    print('funval: %.4e %.4e %.4e %.4e'%(Tsurfdist, Eelsurf, Epensurf, dr))
# Out:
# Period 0
# Traction residual: 3.0814e+00 Pa
# Elastic energy: 1.4872e-04 pJ
# funval: 3.0814e-02 7.9729e-03 1.6305e-04 3.8950e-02
# Period 1
# Traction residual: 1.1564e+00 Pa
# Elastic energy: 1.9264e-04 pJ
# funval: 1.1564e-02 1.0327e-02 2.3764e-04 2.2129e-02
# Period 2
# Traction residual: 1.0935e+00 Pa
# Elastic energy: 1.8167e-04 pJ
# funval: 1.0935e-02 9.7391e-03 1.5234e-04 2.0826e-02
# Period 3
# Traction residual: 1.0072e+00 Pa
# Elastic energy: 1.8591e-04 pJ
# funval: 1.0072e-02 9.9663e-03 1.3187e-04 2.0170e-02
# Period 4
# Traction residual: 9.7283e-01 Pa
# Elastic energy: 1.8110e-04 pJ
# funval: 9.7283e-03 9.7085e-03 1.2951e-04 1.9566e-02
# Period 5
# Traction residual: 9.2139e-01 Pa
# Elastic energy: 1.8186e-04 pJ
# funval: 9.2139e-03 9.7493e-03 1.4090e-04 1.9104e-02
# Period 6
# Traction residual: 9.2360e-01 Pa
# Elastic energy: 1.6921e-04 pJ
# funval: 9.2360e-03 9.0710e-03 1.5523e-04 1.8462e-02
# Period 7
# Traction residual: 8.7192e-01 Pa
# Elastic energy: 1.6585e-04 pJ
# funval: 8.7192e-03 8.8913e-03 1.2444e-04 1.7735e-02
# Period 8
# Traction residual: 8.4630e-01 Pa
# Elastic energy: 1.4625e-04 pJ
# funval: 8.4630e-03 7.8404e-03 2.0429e-04 1.6508e-02
# Period 9
# Traction residual: 7.6350e-01 Pa
# Elastic energy: 1.4028e-04 pJ
# funval: 7.6350e-03 7.5201e-03 1.1783e-04 1.5273e-02
# Period 10
# Traction residual: 7.4874e-01 Pa
# Elastic energy: 1.2779e-04 pJ
# funval: 7.4874e-03 6.8507e-03 1.6470e-04 1.4503e-02
# Period 11
# Traction residual: 7.1234e-01 Pa
# Elastic energy: 1.2485e-04 pJ
# funval: 7.1234e-03 6.6929e-03 1.1341e-04 1.3930e-02
# Period 12
# Traction residual: 6.9761e-01 Pa
# Elastic energy: 1.2080e-04 pJ
# funval: 6.9761e-03 6.4760e-03 1.2054e-04 1.3573e-02
# Period 13
# Traction residual: 6.8242e-01 Pa
# Elastic energy: 1.2005e-04 pJ
# funval: 6.8242e-03 6.4358e-03 1.1335e-04 1.3373e-02
# Period 14
# Traction residual: 6.7541e-01 Pa
# Elastic energy: 1.1940e-04 pJ
# funval: 6.7541e-03 6.4009e-03 1.1126e-04 1.3266e-02
# Period 15
# Traction residual: 6.7256e-01 Pa
# Elastic energy: 1.1920e-04 pJ
# funval: 6.7256e-03 6.3904e-03 1.0996e-04 1.3226e-02
# Period 16
# Traction residual: 6.6759e-01 Pa
# Elastic energy: 1.1872e-04 pJ
# funval: 6.6759e-03 6.3643e-03 1.1238e-04 1.3153e-02
# Period 17
# Traction residual: 6.6401e-01 Pa
# Elastic energy: 1.1859e-04 pJ
# funval: 6.6401e-03 6.3574e-03 1.0350e-04 1.3101e-02
# Period 18
# Traction residual: 6.4085e-01 Pa
# Elastic energy: 1.1805e-04 pJ
# funval: 6.4085e-03 6.3284e-03 9.9223e-05 1.2836e-02
# Period 19
# Traction residual: 6.3236e-01 Pa
# Elastic energy: 1.1717e-04 pJ
# funval: 6.3236e-03 6.2812e-03 7.4433e-05 1.2679e-02
# Period 20
# Traction residual: 6.3341e-01 Pa
# Elastic energy: 1.1560e-04 pJ
# funval: 6.3341e-03 6.1973e-03 7.4167e-05 1.2606e-02
# Period 21
# Traction residual: 6.3118e-01 Pa
# Elastic energy: 1.1543e-04 pJ
# funval: 6.3118e-03 6.1880e-03 7.0609e-05 1.2570e-02
# Period 22
# Traction residual: 6.2898e-01 Pa
# Elastic energy: 1.1522e-04 pJ
# funval: 6.2898e-03 6.1768e-03 6.9848e-05 1.2536e-02
# Period 23
# Traction residual: 6.2780e-01 Pa
# Elastic energy: 1.1511e-04 pJ
# funval: 6.2780e-03 6.1708e-03 6.8423e-05 1.2517e-02
# Period 24
# Traction residual: 6.2353e-01 Pa
# Elastic energy: 1.1483e-04 pJ
# funval: 6.2353e-03 6.1559e-03 7.1225e-05 1.2462e-02
# Period 25
# Traction residual: 6.2039e-01 Pa
# Elastic energy: 1.1456e-04 pJ
# funval: 6.2039e-03 6.1416e-03 6.3908e-05 1.2409e-02
# Period 26
# Traction residual: 6.0965e-01 Pa
# Elastic energy: 1.1394e-04 pJ
# funval: 6.0965e-03 6.1083e-03 6.6839e-05 1.2272e-02
# Period 27
# Traction residual: 6.0631e-01 Pa
# Elastic energy: 1.1372e-04 pJ
# funval: 6.0631e-03 6.0963e-03 5.8797e-05 1.2218e-02
# Period 28
# Traction residual: 5.9920e-01 Pa
# Elastic energy: 1.1327e-04 pJ
# funval: 5.9920e-03 6.0722e-03 6.6567e-05 1.2131e-02
# Period 29
# Traction residual: 5.9705e-01 Pa
# Elastic energy: 1.1294e-04 pJ
# funval: 5.9705e-03 6.0548e-03 5.3059e-05 1.2078e-02
# Period 30
# Traction residual: 5.9667e-01 Pa
# Elastic energy: 1.1292e-04 pJ
# funval: 5.9667e-03 6.0536e-03 5.3170e-05 1.2073e-02

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 3), sharex=True)
ax[0].semilogy(drlist  , label='$Target f$')
ax[0].semilogy(Treslist, label='$T_{res}$')
ax[0].semilogy(Eel_list, label='$E_{el}$')
ax[0].semilogy(Epenlist, label='$E_{pen}$')
ax[0].legend()
ax[1].semilogy(np.array(Treslist)*mu0); ax[1].set_title('Traction residual (Pa)');
ax[2].semilogy(np.array(Eel_list)*(r0/1e6)**3*mu0*1e12); ax[2].set_title('Elastic energy (pJ)')
if savefig:
    plt.tight_layout(); plt.savefig(savename+'_curve.png', transparent=True)
plt.show()

# %%
T0dist = Tvec2Tres(T0vec, lJmax, isTfv=isTfv, norm_order=myord)
E0el = np.vdot(U0vec, T0vec).real*2*np.pi
print('Traction residual: %.4e Pa'%(T0dist*mu0))
print('Elastic energy: %.4e pJ'%(E0el*(r0/1e6)**3*mu0*1e12))
print('funval: %.4e %.4e'%(T0dist, E0el))
# Out:
# Traction residual: 5.9667e-01 Pa
# Elastic energy: 1.1292e-04 pJ
# funval: 5.9667e-03 6.0536e-03

# %%
print('Evaluate Displacement and Traction in Cartesian Coordinates for plotting 3d shape...')
umesh1 = SHVec2mesh(U0vec, lmax=lJmax, SphCoord=False, Complex=True)
tmesh1 = SHVec2mesh(T0vec*mu0, lmax=lJmax, SphCoord=False, Complex=True)
umesh1_fine = SHVec2mesh(U0vec, lmax=lmax_plot, SphCoord=False, Complex=True)
tmesh1_fine = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=False, Complex=True)
# Out:
# Evaluate Displacement and Traction in Cartesian Coordinates for plotting 3d shape...

# %%
print('Visualize the nodes in 3D...')
fig, ax = visSH3d(umesh1, cmesh=tmesh1, r0=r0, show=False, elevation=0, azimuth=0, surface=False, figsize=plt.figaspect(1))
nTfv = np.logical_not(Tfv)
ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
if savefig:
    plt.tight_layout(); plt.savefig(savename+'_compare.png', transparent=True)
#plt.show()
# Out:
# Visualize the nodes in 3D...

# %%
# %matplotlib notebook
print('Visualize the shape in 3D...')
fig, ax = visSH3d(umesh1_fine, cmesh=tmesh1_fine, 
                  r0=r0, show=False, vmin=-50, vmax=50,
                  elevation=0, azimuth=0,
                  surface=True, figsize=plt.figaspect(1))#(4,4))

# reference data
#ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
#ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
#ax.set_title('Front view')
ax.set_axis_off()
if savefig:
    plt.tight_layout(); plt.savefig(savename+'_front.png', transparent=True)
plt.show()
# Out:
# Visualize the shape in 3D...

# %%
# %matplotlib notebook
print('Visualize the shape in 3D...')
fig, ax = visSH3d(umesh1_fine, cmesh=tmesh1_fine, 
                  r0=r0, show=False, vmin=-50, vmax=50,
                  elevation=0, azimuth=-90,
                  surface=True, figsize=(4,4))

# reference data
#ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
#ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
#ax.set_title('Left view')
ax.set_axis_off()
if savefig:
    plt.tight_layout(); plt.savefig(savename+'_left.png', transparent=True)
plt.show()
# Out:
# Visualize the shape in 3D...

# %%
# %matplotlib notebook
print('Visualize the shape in 3D...')
fig, ax = visSH3d(umesh1_fine, cmesh=tmesh1_fine, 
                  r0=r0, show=False, vmin=-50, vmax=50,
                  elevation=90, azimuth=0,
                  surface=True, figsize=(4,4))

# reference data
#ax.scatter3D(Vp[Tfv, 0], Vp[Tfv, 1], Vp[Tfv, 2], marker='^', s=10)
#ax.scatter3D(Vp[nTfv, 0], Vp[nTfv, 1], Vp[nTfv, 2], marker='^', s=10)
#ax.set_title('Top view')
ax.set_axis_off()

if savefig:
    plt.tight_layout(); plt.savefig(savename+'_top.png', transparent=True)
plt.show()
# Out:
# Visualize the shape in 3D...

# %%
if savefig:
    Vlat, Vlon = pyshtools.expand.GLQGridCoord(lJmax)
    umesh_Cart = SHVec2mesh(U0vec*r0, lmax=lmax_plot, SphCoord=False, Complex=True)
    tmesh_Cart = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=False, Complex=True)
    umesh_Sph = SHVec2mesh(U0vec*r0, lmax=lmax_plot, SphCoord=True, Complex=True)
    tmesh_Sph = SHVec2mesh(T0vec*mu0, lmax=lmax_plot, SphCoord=True, Complex=True)
    #ugrid_Cart = SHVec2mesh(U0vec*r0, lat=Vlat, lon=Vlon, lmax=lmax_plot, SphCoord=False, Complex=True)
    #tgrid_Cart = SHVec2mesh(T0vec*mu0, lat=Vlat, lon=Vlon, lmax=lmax_plot, SphCoord=False, Complex=True)
    #ugrid_Sph = SHVec2mesh(U0vec*r0, lat=Vlat, lon=Vlon, lmax=lmax_plot, SphCoord=True, Complex=True)
    #tgrid_Sph = SHVec2mesh(T0vec*mu0, lat=Vlat, lon=Vlon, lmax=lmax_plot, SphCoord=True, Complex=True)
    savemat(savename+'.mat', {'umesh_Cart':umesh_Cart, 'tmesh_Cart':tmesh_Cart,
                              'umesh_Sph': umesh_Sph,  'tmesh_Sph': tmesh_Sph,
                              #'ugrid_Cart':ugrid_Cart, 'tgrid_Cart':tgrid_Cart,
                              #'ugrid_Sph': ugrid_Sph,  'tgrid_Sph': tgrid_Sph,
                              'lat': Vlat, 'lon': Vlon, 'r0': r0,  'mu0': mu0, 'nu0': nu0})
